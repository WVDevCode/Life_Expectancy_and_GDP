# %% [markdown]
# Successfully imported necessary libraries for inferential analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels as sm
import scipy as sc
import seaborn as sns
