# %% [markdown]
# # Import Libraries

# %% [markdown]
# Successfully imported necessary libraries for descriptive analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels as sm
import scipy as sc
import seaborn as sns

# %% [markdown]
# # Import datasets

# %% [markdown]
# Successfully save Life_expectancy_cleaned_1.csv file to life_expectancy variable

# %%
life_expectancy = pd.read_csv('../Datasets/Cleaned_datasets/Life_expectancy_cleaned_1.csv').drop(columns=['Unnamed: 0'])

# %% [markdown]
# Import dataframes for descriptive analysis

# %%
highest_grossing = pd.read_csv('../Datasets/Cleaned_datasets/EDA_Datasets/Top_Grossing_Countries-per_capita.csv').drop(columns=['Unnamed: 0'])
lowest_grossing = pd.read_csv('../Datasets/Cleaned_datasets/EDA_Datasets/Lowest_Grossing_Countries-per_capita.csv').drop(columns=['Unnamed: 0'])

# %% [markdown]
# # Organizing datasets

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# Create dataframe containing life expectancy mean, maximum, minimum and median values of all countries by year

# %% [markdown]
# ## Life Expectancy

# %% [markdown]
# ### Mean

# %% [markdown]
# #### All regions

# %%
years_list_mean = []
means_list = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['life_expectancy'].where(life_expectancy.year == year))
    years_list_mean.append(year)
    means_list.append(np.round(mean, 2))
all_means_dict = {'year': years_list_mean, 'mean': means_list}

le_all_means_df = pd.DataFrame(all_means_dict)

# %% [markdown]
# #### African region

# %%
years_list_mean = []
means_list = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_mean.append(year)
    means_list.append(np.round(mean, 2))
all_means_dict = {'year': years_list_mean, 'mean': means_list}

le_all_means_africa_df = pd.DataFrame(all_means_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_mean = []
means_list = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_mean.append(year)
    means_list.append(np.round(mean, 2))
all_means_dict = {'year': years_list_mean, 'mean': means_list}

le_all_means_asia_df = pd.DataFrame(all_means_dict)

# %% [markdown]
# #### American region

# %%
years_list_mean = []
means_list = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_mean.append(year)
    means_list.append(np.round(mean, 2))
all_means_dict = {'year': years_list_mean, 'mean': means_list}

le_all_means_american_df = pd.DataFrame(all_means_dict)

# %% [markdown]
# #### European region

# %%
years_list_mean = []
means_list = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_mean.append(year)
    means_list.append(np.round(mean, 2))
all_means_dict = {'year': years_list_mean, 'mean': means_list}

le_all_means_european_df = pd.DataFrame(all_means_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_mean = []
means_list = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_mean.append(year)
    means_list.append(np.round(mean, 2))
all_means_dict = {'year': years_list_mean, 'mean': means_list}

le_all_means_oceania_df = pd.DataFrame(all_means_dict)

# %% [markdown]
# ### Max

# %% [markdown]
# #### All regions

# %%
years_list_max = []
max_list = []
max_countries = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['life_expectancy'][life_expectancy.year == year])
    max_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['life_expectancy'] == max)].values[0]
    years_list_max.append(year)
    max_list.append(max)
    max_countries.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list, 'max_countries': max_countries}

le_all_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### African region

# %%
years_list_max = []
max_list = []
max_countries = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['life_expectancy'][(life_expectancy.year == year) & (life_expectancy['region'] == 'African region')])
    max_country = life_expectancy['country'][(life_expectancy.year == year)  & (life_expectancy['life_expectancy'] == max)].values[0]
    years_list_max.append(year)
    max_list.append(max)
    max_countries.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list, 'max_countries': max_countries}

le_african_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_max = []
max_list = []
max_countries = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['life_expectancy'][(life_expectancy.year == year) & (life_expectancy['region'] == 'Asian region')])
    max_country = life_expectancy['country'][(life_expectancy.year == year)  & (life_expectancy['life_expectancy'] == max)].values[0]
    years_list_max.append(year)
    max_list.append(max)
    max_countries.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list, 'max_countries': max_countries}

le_asian_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### American region

# %%
years_list_max = []
max_list = []
max_countries = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['life_expectancy'][(life_expectancy.year == year) & (life_expectancy['region'] == 'American region')])
    max_country = life_expectancy['country'][(life_expectancy.year == year)  & (life_expectancy['life_expectancy'] == max)].values[0]
    years_list_max.append(year)
    max_list.append(max)
    max_countries.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list, 'max_countries': max_countries}

le_american_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### European region

# %%
years_list_max = []
max_list = []
max_countries = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['life_expectancy'][(life_expectancy.year == year) & (life_expectancy['region'] == 'European region')])
    max_country = life_expectancy['country'][(life_expectancy.year == year)  & (life_expectancy['life_expectancy'] == max)].values[0]
    years_list_max.append(year)
    max_list.append(max)
    max_countries.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list, 'max_countries': max_countries}

le_european_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Oceania reggion

# %%
years_list_max = []
max_list = []
max_countries = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['life_expectancy'][(life_expectancy.year == year) & (life_expectancy['region'] == 'Oceania region')])
    max_country = life_expectancy['country'][(life_expectancy.year == year)  & (life_expectancy['life_expectancy'] == max)].values[0]
    years_list_max.append(year)
    max_list.append(max)
    max_countries.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list, 'max_countries': max_countries}

le_oceania_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# ### Minimum

# %% [markdown]
# #### All countries

# %%
years_list_min = []
min_list = []
min_countries = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['life_expectancy'].where(life_expectancy.year == year))
    min_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['life_expectancy'] == min)].values[0]
    years_list_min.append(year)
    min_list.append(min)
    min_countries.append(min_country)
all_min_dict = {'year': years_list_min, 'minimum': min_list, 'min_countries' : min_countries}

le_all_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### African region

# %%
years_list_min = []
min_list = []
min_countries = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['life_expectancy'][(life_expectancy.year == year) & (life_expectancy['region'] == 'African region')])
    min_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['life_expectancy'] == min)].values[0]
    years_list_min.append(year)
    min_list.append(min)
    min_countries.append(min_country)
all_min_dict = {'year': years_list_min, 'minimum': min_list, 'min_countries' : min_countries}

le_africa_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_min = []
min_list = []
min_countries = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['life_expectancy'][(life_expectancy.year == year) & (life_expectancy['region'] == 'Asian region')])
    min_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['life_expectancy'] == min)].values[0]
    years_list_min.append(year)
    min_list.append(min)
    min_countries.append(min_country)
all_min_dict = {'year': years_list_min, 'minimum': min_list, 'min_countries' : min_countries}

le_asia_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### American region

# %%
years_list_min = []
min_list = []
min_countries = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['life_expectancy'][(life_expectancy.year == year) & (life_expectancy['region'] == 'American region')])
    min_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['life_expectancy'] == min)].values[0]
    years_list_min.append(year)
    min_list.append(min)
    min_countries.append(min_country)
all_min_dict = {'year': years_list_min, 'minimum': min_list, 'min_countries' : min_countries}

le_america_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### European region

# %%
years_list_min = []
min_list = []
min_countries = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['life_expectancy'][(life_expectancy.year == year) & (life_expectancy['region'] == 'European region')])
    min_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['life_expectancy'] == min)].values[0]
    years_list_min.append(year)
    min_list.append(min)
    min_countries.append(min_country)
all_min_dict = {'year': years_list_min, 'minimum': min_list, 'min_countries' : min_countries}

le_europe_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Oceania reggion

# %%
years_list_min = []
min_list = []
min_countries = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['life_expectancy'][(life_expectancy.year == year) & (life_expectancy['region'] == 'Oceania region')])
    min_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['life_expectancy'] == min)].values[0]
    years_list_min.append(year)
    min_list.append(min)
    min_countries.append(min_country)
all_min_dict = {'year': years_list_min, 'minimum': min_list, 'min_countries' : min_countries}

le_oceania_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# ### Median

# %% [markdown]
# #### All countries

# %%
years_list_median = []
median_list_life_exp = []
for year in range(2000, 2016):
    median = np.median((life_expectancy['life_expectancy'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_median.append(year)
    median_list_life_exp.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_life_exp}

le_all_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### African region

# %%
years_list_median = []
median_list_life_exp = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_median.append(year)
    median_list_life_exp.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_life_exp}

le_african_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_median = []
median_list_life_exp = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_median.append(year)
    median_list_life_exp.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_life_exp}

le_asian_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### American region

# %%
years_list_median = []
median_list_life_exp = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_median.append(year)
    median_list_life_exp.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_life_exp}

le_american_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### European region

# %%
years_list_median = []
median_list_life_exp = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_median.append(year)
    median_list_life_exp.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_life_exp}

le_european_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_median = []
median_list_life_exp = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_median.append(year)
    median_list_life_exp.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_life_exp}

le_oceania_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# ### Standard Deviation

# %% [markdown]
# #### All countries

# %%
years_list_std = []
std_list = []
for year in range(2000, 2016):
    std = np.std((life_expectancy['life_expectancy'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_std.append(year)
    std_list.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list}

le_all_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### African region

# %%
years_list_std = []
std_list_life_exp = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_std.append(year)
    std_list_life_exp.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_life_exp}

le_african_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_std = []
std_list_life_exp = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_std.append(year)
    std_list_life_exp.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_life_exp}

le_asian_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### American region

# %%
years_list_std = []
std_list_life_exp = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_std.append(year)
    std_list_life_exp.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_life_exp}

le_american_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### European region

# %%
years_list_std = []
std_list_life_exp = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_std.append(year)
    std_list_life_exp.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_life_exp}

le_european_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_std = []
std_list_life_exp = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_std.append(year)
    std_list_life_exp.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_life_exp}

le_oceania_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# ### Inter-Quartile Range

# %% [markdown]
# #### All countries

# %%
years_list_iqr = []
iqr_list = []
iqr_q1_list_life_exp = []
iqr_q3_list_life_exp = []
for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['life_expectancy'][life_expectancy['year'] == year], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list.append(round(iqr, 2))
    iqr_q1_list_life_exp.append(round(q1, 2))
    iqr_q3_list_life_exp.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_life_exp, '75%': iqr_q3_list_life_exp, 'iqr': iqr_list}

le_all_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### African region

# %%
years_list_iqr = []
iqr_list_life_exp = []
iqr_q1_list_life_exp = []
iqr_q3_list_life_exp = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_life_exp.append(round(iqr, 2))
    iqr_q1_list_life_exp.append(round(q1, 2))
    iqr_q3_list_life_exp.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_life_exp, '75%': iqr_q3_list_life_exp, 'iqr': iqr_list_life_exp}

le_african_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_iqr = []
iqr_list_life_exp = []
iqr_q1_list_life_exp = []
iqr_q3_list_life_exp = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_life_exp.append(round(iqr, 2))
    iqr_q1_list_life_exp.append(round(q1, 2))
    iqr_q3_list_life_exp.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_life_exp, '75%': iqr_q3_list_life_exp, 'iqr': iqr_list_life_exp}

le_asian_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### American region

# %%
years_list_iqr = []
iqr_list_life_exp = []
iqr_q1_list_life_exp = []
iqr_q3_list_life_exp = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_life_exp.append(round(iqr, 2))
    iqr_q1_list_life_exp.append(round(q1, 2))
    iqr_q3_list_life_exp.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_life_exp, '75%': iqr_q3_list_life_exp, 'iqr': iqr_list_life_exp}

le_american_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### European region

# %%
years_list_iqr = []
iqr_list_life_exp = []
iqr_q1_list_life_exp = []
iqr_q3_list_life_exp = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_life_exp.append(round(iqr, 2))
    iqr_q1_list_life_exp.append(round(q1, 2))
    iqr_q3_list_life_exp.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_life_exp, '75%': iqr_q3_list_life_exp, 'iqr': iqr_list_life_exp}

le_european_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_iqr = []
iqr_list_life_exp = []
iqr_q1_list_life_exp = []
iqr_q3_list_life_exp = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_life_exp.append(round(iqr, 2))
    iqr_q1_list_life_exp.append(round(q1, 2))
    iqr_q3_list_life_exp.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_life_exp, '75%': iqr_q3_list_life_exp, 'iqr': iqr_list_life_exp}

le_oceania_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# ### Combining stats into single dataframes by groupin and converting it into a csv file

# %%
# Al countries
descriptive_stats_life_exp = le_all_means_df.merge(le_all_max_df, on='year').merge(le_all_min_df, on='year').merge(le_all_median_df, on='year').merge(le_all_std_df, on='year').merge(le_all_iqr_df, on='year')
descriptive_stats_life_exp.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_All_Dfs/Descriptive_Stats_All_Life_expectancy.csv')

# Africa
descriptive_stats_life_exp_africa =le_all_means_africa_df.merge(le_african_max_df, on='year').merge(le_africa_min_df, on='year').merge(le_african_median_df, on='year').merge(le_african_std_df, on='year').merge(le_african_iqr_df, on='year')
descriptive_stats_life_exp_africa.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Life_Expectancy/Descriptive_Stats_Africa_Life_expectancy.csv')

# Asia
descriptive_stats_life_exp_asia =le_all_means_asia_df.merge(le_asian_max_df, on='year').merge(le_asia_min_df, on='year').merge(le_asian_median_df, on='year').merge(le_asian_std_df, on='year').merge(le_asian_iqr_df, on='year')
descriptive_stats_life_exp_asia.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Life_Expectancy/Descriptive_Stats_Asia_Life_expectancy.csv')

# America
descriptive_stats_life_exp_america =le_all_means_american_df.merge(le_american_max_df, on='year').merge(le_america_min_df, on='year').merge(le_american_median_df, on='year').merge(le_american_std_df, on='year').merge(le_american_iqr_df, on='year')
descriptive_stats_life_exp_america.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Life_Expectancy/Descriptive_Stats_America_Life_expectancy.csv')

# Europe
descriptive_stats_life_exp_europe =le_all_means_european_df.merge(le_european_max_df, on='year').merge(le_europe_min_df, on='year').merge(le_european_median_df, on='year').merge(le_european_std_df, on='year').merge(le_european_iqr_df, on='year')
descriptive_stats_life_exp_europe.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Life_Expectancy/Descriptive_Stats_Europe_Life_expectancy.csv')

# Oceania
descriptive_stats_life_exp_oceania =le_all_means_oceania_df.merge(le_oceania_max_df, on='year').merge(le_oceania_min_df, on='year').merge(le_oceania_median_df, on='year').merge(le_oceania_std_df, on='year').merge(le_oceania_iqr_df, on='year')
descriptive_stats_life_exp_oceania.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Life_Expectancy/Descriptive_Stats_Oceania_Life_expectancy.csv')

# %% [markdown]
# ## Adult Mortality

# %% [markdown]
# ### Mean

# %% [markdown]
# #### All countries

# %%
years_list_mean = []
means_list_ad_mortality = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['adult_mortality'].where(life_expectancy.year == year))
    years_list_mean.append(year)
    means_list_ad_mortality.append(np.round(mean, 2))
all_means_dict = {'year': years_list_mean, 'mean': means_list_ad_mortality}

am_all_means_df = pd.DataFrame(all_means_dict)

# %% [markdown]
# #### African region

# %%
years_list_mean = []
mean_list_ad_mortality = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_mean.append(year)
    mean_list_ad_mortality.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_ad_mortality}

am_african_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_mean = []
mean_list_ad_mortality = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_mean.append(year)
    mean_list_ad_mortality.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_ad_mortality}

am_asian_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### American region

# %%
years_list_mean = []
mean_list_ad_mortality = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_mean.append(year)
    mean_list_ad_mortality.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_ad_mortality}

am_american_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### European region

# %%
years_list_mean = []
mean_list_ad_mortality = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_mean.append(year)
    mean_list_ad_mortality.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_ad_mortality}

am_european_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_mean = []
mean_list_ad_mortality = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_mean.append(year)
    mean_list_ad_mortality.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_ad_mortality}

am_oceania_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# ### Max

# %% [markdown]
# #### Al regions

# %%
years_list_max = []
max_list_ad_mortality = []
max_countries_ad_mortality = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['adult_mortality'][life_expectancy.year == year])
    max_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['adult_mortality'] == max)].values[0]
    years_list_max.append(year)
    max_list_ad_mortality.append(max)
    max_countries_ad_mortality.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list_ad_mortality, 'max_countries': max_countries_ad_mortality}

am_all_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### African region

# %%
years_list_max = []
max_list = []
max_countries = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['adult_mortality'][(life_expectancy.year == year) & (life_expectancy['region'] == 'African region')])
    max_country = life_expectancy['country'][(life_expectancy.year == year)  & (life_expectancy['adult_mortality'] == max)].values[0]
    years_list_max.append(year)
    max_list.append(max)
    max_countries.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list, 'max_countries': max_countries}

am_african_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_max = []
max_list = []
max_countries = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['adult_mortality'][(life_expectancy.year == year) & (life_expectancy['region'] == 'Asian region')])
    max_country = life_expectancy['country'][(life_expectancy.year == year)  & (life_expectancy['adult_mortality'] == max)].values[0]
    years_list_max.append(year)
    max_list.append(max)
    max_countries.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list, 'max_countries': max_countries}

am_asian_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### American region

# %%
years_list_max = []
max_list = []
max_countries = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['adult_mortality'][(life_expectancy['region'] == 'American region') & (life_expectancy.year == year)])
    max_country = life_expectancy['country'][(life_expectancy.year == year)  & (life_expectancy['adult_mortality'] == max) & (life_expectancy['region'] == 'American region')].values[0]
    years_list_max.append(year)
    max_list.append(max)
    max_countries.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list, 'max_countries': max_countries}

am_merican_max_df = pd.DataFrame(all_max_dict)
print(max_countries)
# Out:
# ['Haiti', 'Haiti', 'Haiti', 'Haiti', 'Haiti', 'Haiti', 'Haiti', 'Haiti', 'Haiti', 'Haiti', 'Haiti', 'Haiti', 'Haiti', 'Haiti', 'Haiti', 'Haiti']

# %% [markdown]
# #### European region

# %%
years_list_max = []
max_list = []
max_countries = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['adult_mortality'][(life_expectancy.year == year) & (life_expectancy['region'] == 'European region')])
    max_country = life_expectancy['country'][(life_expectancy.year == year)  & (life_expectancy['adult_mortality'] == max)].values[0]
    years_list_max.append(year)
    max_list.append(max)
    max_countries.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list, 'max_countries': max_countries}

am_european_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Oceania reggion

# %%
years_list_max = []
max_list = []
max_countries = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['adult_mortality'][(life_expectancy.year == year) & (life_expectancy['region'] == 'Oceania region')])
    max_country = life_expectancy['country'][(life_expectancy.year == year)  & (life_expectancy['adult_mortality'] == max)].values[0]
    years_list_max.append(year)
    max_list.append(max)
    max_countries.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list, 'max_countries': max_countries}

am_oceania_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# ### Minimum

# %% [markdown]
# #### All regions

# %%
years_list_min = []
min_list_ad_mortality = []
min_countries_ad_mortality = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['adult_mortality'].where(life_expectancy.year == year))
    min_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['adult_mortality'] == min)].values[0]
    years_list_min.append(year)
    min_list_ad_mortality.append(min)
    min_countries_ad_mortality.append(min_country)
all_min_dict = {'year': years_list_min, 'minimum': min_list_ad_mortality, 'min_countries' : min_countries_ad_mortality}

am_all_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### African region

# %%
years_list_min = []
min_list_ad_mortality = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_min.append(year)
    min_list_ad_mortality.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_ad_mortality}

am_african_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_min = []
min_list_ad_mortality = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_min.append(year)
    min_list_ad_mortality.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_ad_mortality}

am_asian_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### American region

# %%
years_list_min = []
min_list_ad_mortality = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_min.append(year)
    min_list_ad_mortality.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_ad_mortality}

am_american_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### European region

# %%
years_list_min = []
min_list_ad_mortality = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_min.append(year)
    min_list_ad_mortality.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_ad_mortality}

am_european_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_min = []
min_list_ad_mortality = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_min.append(year)
    min_list_ad_mortality.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_ad_mortality}

am_oceania_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# ### Median

# %% [markdown]
# #### All countriess

# %%
years_list_median = []
median_list_ad_mortality = []
for year in range(2000, 2016):
    median = np.median((life_expectancy['adult_mortality'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_median.append(year)
    median_list_ad_mortality.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_ad_mortality}

am_all_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### African region

# %%
years_list_median = []
median_list_ad_mortality = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_median.append(year)
    median_list_ad_mortality.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_ad_mortality}

am_african_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_median = []
median_list_ad_mortality = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_median.append(year)
    median_list_ad_mortality.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_ad_mortality}

am_asian_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### American region

# %%
years_list_median= []
median_list_ad_mortality = []
for year in range(2000, 2016):
    median= np.median(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_median.append(year)
    median_list_ad_mortality.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_ad_mortality}

am_american_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### European region

# %%
years_list_median = []
median_list_ad_mortality = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_median.append(year)
    median_list_ad_mortality.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_ad_mortality}

am_european_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_median = []
median_list_ad_mortality = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_median.append(year)
    median_list_ad_mortality.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_ad_mortality}

am_oceania_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# ### Standard Deviation

# %% [markdown]
# #### All countries

# %%
years_list_std = []
std_list = []
for year in range(2000, 2016):
    std = np.std((life_expectancy['adult_mortality'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_std.append(year)
    std_list.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list}

am_all_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### African region

# %%
years_list_std = []
std_list_ad_mortality = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_std.append(year)
    std_list_ad_mortality.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_ad_mortality}

am_african_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_std = []
std_list_ad_mortality = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_std.append(year)
    std_list_ad_mortality.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_ad_mortality}

am_asian_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### American region

# %%
years_list_std = []
std_list_ad_mortality = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_std.append(year)
    std_list_ad_mortality.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_ad_mortality}

am_american_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### European region

# %%
years_list_std = []
std_list_ad_mortality = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_std.append(year)
    std_list_ad_mortality.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_ad_mortality}

am_european_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_std = []
std_list_ad_mortality = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_std.append(year)
    std_list_ad_mortality.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_ad_mortality}

am_oceania_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# ### Inter-Quartile Range

# %% [markdown]
# #### All countries

# %%
years_list_iqr = []
iqr_list = []
iqr_q1_list_adult_mortality = []
iqr_q3_list_adult_mortality = []
for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['adult_mortality'][life_expectancy['year'] == year], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list.append(round(iqr, 2))
    iqr_q1_list_adult_mortality.append(round(q1, 2))
    iqr_q3_list_adult_mortality.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_adult_mortality, '75%': iqr_q3_list_adult_mortality, 'iqr': iqr_list}

am_all_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### African region

# %%
years_list_iqr = []
iqr_list_adult_mortality = []
iqr_q1_list_adult_mortality = []
iqr_q3_list_adult_mortality = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_adult_mortality.append(round(iqr, 2))
    iqr_q1_list_adult_mortality.append(round(q1, 2))
    iqr_q3_list_adult_mortality.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_adult_mortality, '75%': iqr_q3_list_adult_mortality, 'iqr': iqr_list_adult_mortality}

am_african_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_iqr = []
iqr_list_adult_mortality = []
iqr_q1_list_adult_mortality = []
iqr_q3_list_adult_mortality = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_adult_mortality.append(round(iqr, 2))
    iqr_q1_list_adult_mortality.append(round(q1, 2))
    iqr_q3_list_adult_mortality.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_adult_mortality, '75%': iqr_q3_list_adult_mortality, 'iqr': iqr_list_adult_mortality}

am_asian_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### American region

# %%
years_list_iqr = []
iqr_list_adult_mortality = []
iqr_q1_list_adult_mortality = []
iqr_q3_list_adult_mortality = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_adult_mortality.append(round(iqr, 2))
    iqr_q1_list_adult_mortality.append(round(q1, 2))
    iqr_q3_list_adult_mortality.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_adult_mortality, '75%': iqr_q3_list_adult_mortality, 'iqr': iqr_list_adult_mortality}

am_american_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### European region

# %%
years_list_iqr = []
iqr_list_adult_mortality = []
iqr_q1_list_adult_mortality = []
iqr_q3_list_adult_mortality = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_adult_mortality.append(round(iqr, 2))
    iqr_q1_list_adult_mortality.append(round(q1, 2))
    iqr_q3_list_adult_mortality.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_adult_mortality, '75%': iqr_q3_list_adult_mortality, 'iqr': iqr_list_adult_mortality}

am_european_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_iqr = []
iqr_list_adult_mortality = []
iqr_q1_list_adult_mortality = []
iqr_q3_list_adult_mortality = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_adult_mortality.append(round(iqr, 2))
    iqr_q1_list_adult_mortality.append(round(q1, 2))
    iqr_q3_list_adult_mortality.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_adult_mortality, '75%': iqr_q3_list_adult_mortality, 'iqr': iqr_list_adult_mortality}

am_oceania_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# ### Combining stats into single dataframe and converting it into a csv file

# %%
# Al countries
descriptive_stats_adult_mortality =am_all_means_df.merge(am_all_max_df, on='year').merge(am_all_min_df, on='year').merge(am_all_median_df, on='year').merge(am_all_std_df, on='year').merge(am_all_iqr_df, on='year')
descriptive_stats_adult_mortality.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_All_Dfs/Descriptive_Stats_All_Adult_Mortality.csv')

# Africa
descriptive_stats_adult_mortality_africa =am_african_mean_df.merge(am_african_max_df, on='year').merge(am_african_min_df, on='year').merge(am_african_median_df, on='year').merge(am_african_std_df, on='year').merge(am_african_iqr_df, on='year')
descriptive_stats_adult_mortality_africa.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Adult_Mortality/Descriptive_Stats_Africa_Adult_Mortality.csv')

# Asia
descriptive_stats_adult_mortality_asia =am_asian_mean_df.merge(am_asian_max_df, on='year').merge(am_asian_min_df, on='year').merge(am_asian_median_df, on='year').merge(am_asian_std_df, on='year').merge(am_asian_iqr_df, on='year')
descriptive_stats_adult_mortality_asia.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Adult_Mortality/Descriptive_Stats_Asia_Adult_Mortality.csv')

# America
descriptive_stats_adult_mortality_america = am_american_mean_df.merge(am_merican_max_df, on='year').merge(am_american_min_df, on='year').merge(am_american_median_df, on='year').merge(am_american_std_df, on='year').merge(am_american_iqr_df, on='year')
descriptive_stats_adult_mortality_america.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Adult_Mortality/Descriptive_Stats_America_Adult_Mortality.csv')

# Europe
descriptive_stats_adult_mortality_europe =am_european_mean_df.merge(am_european_max_df, on='year').merge(am_european_min_df, on='year').merge(am_european_median_df, on='year').merge(am_european_std_df, on='year').merge(am_european_iqr_df, on='year')
descriptive_stats_adult_mortality_europe.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Adult_Mortality/Descriptive_Stats_Europe_Adult_Mortality.csv')

# Oceania
descriptive_stats_adult_mortality_oceania =am_oceania_median_df.merge(am_oceania_max_df, on='year').merge(am_oceania_min_df, on='year').merge(am_oceania_median_df, on='year').merge(am_oceania_std_df, on='year').merge(am_oceania_iqr_df, on='year')
descriptive_stats_adult_mortality_oceania.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Adult_Mortality/Descriptive_Stats_Oceania_Adult_Mortality.csv')

# %% [markdown]
# ## Infant Deaths

# %% [markdown]
# ### Mean

# %% [markdown]
# #### Al countries

# %%
years_list_mean = []
means_list_infant_deaths = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['infant_deaths'].where(life_expectancy.year == year))
    years_list_mean.append(year)
    means_list_infant_deaths.append(np.round(mean, 2))
all_means_dict = {'year': years_list_mean, 'mean': means_list_infant_deaths}

all_means_df = pd.DataFrame(all_means_dict)

# %% [markdown]
# #### African region

# %%
years_list_mean = []
mean_list_infant_mortality = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_mean.append(year)
    mean_list_infant_mortality.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_infant_mortality}

african_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_mean = []
mean_list_infant_mortality = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_mean.append(year)
    mean_list_infant_mortality.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_infant_mortality}

asian_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### American region

# %%
years_list_mean= []
mean_list_infant_mortality = []
for year in range(2000, 2016):
    mean= np.mean(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_mean.append(year)
    mean_list_infant_mortality.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_infant_mortality}

american_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### European region

# %%
years_list_mean = []
mean_list_infant_mortality = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_mean.append(year)
    mean_list_infant_mortality.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_infant_mortality}

european_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_mean = []
mean_list_infant_mortality = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_mean.append(year)
    mean_list_infant_mortality.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_infant_mortality}

oceania_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# ### Max

# %% [markdown]
# #### All countries

# %%
years_list_max = []
max_list_infant_deaths = []
max_countries_infant_deaths = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['infant_deaths'][life_expectancy.year == year])
    max_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['infant_deaths'] == max)].values[0]
    years_list_max.append(year)
    max_list_infant_deaths.append(max)
    max_countries_infant_deaths.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list_infant_deaths, 'max_countries': max_countries_infant_deaths}

all_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### African region

# %%
years_list_max = []
max_list_infant_mortality = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_max.append(year)
    max_list_infant_mortality.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_infant_mortality}

african_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_max = []
max_list_infant_mortality = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_max.append(year)
    max_list_infant_mortality.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_infant_mortality}

asian_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### American region

# %%
years_list_max= []
max_list_infant_mortality = []
for year in range(2000, 2016):
    max= np.max(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_max.append(year)
    max_list_infant_mortality.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_infant_mortality}

american_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### European region

# %%
years_list_max = []
max_list_infant_mortality = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_max.append(year)
    max_list_infant_mortality.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_infant_mortality}

european_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_max = []
max_list_infant_mortality = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_max.append(year)
    max_list_infant_mortality.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_infant_mortality}

oceania_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# ### Minimum

# %% [markdown]
# #### All countries

# %%
years_list_min = []
min_list_infant_deaths = []
min_countries_infant_deaths = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['infant_deaths'].where(life_expectancy.year == year))
    min_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['infant_deaths'] == min)].values[0]
    years_list_min.append(year)
    min_list_infant_deaths.append(min)
    min_countries_infant_deaths.append(min_country)
all_min_dict = {'year': years_list_min, 'minimum': min_list_infant_deaths, 'min_countries' : min_countries_infant_deaths}

all_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### African region

# %%
years_list_min = []
min_list_infant_mortality = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_min.append(year)
    min_list_infant_mortality.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_infant_mortality}

african_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_min = []
min_list_infant_mortality = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_min.append(year)
    min_list_infant_mortality.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_infant_mortality}

asian_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### American region

# %%
years_list_min= []
min_list_infant_mortality = []
for year in range(2000, 2016):
    min= np.min(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_min.append(year)
    min_list_infant_mortality.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_infant_mortality}

american_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### European region

# %%
years_list_min = []
min_list_infant_mortality = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_min.append(year)
    min_list_infant_mortality.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_infant_mortality}

european_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_min = []
min_list_infant_mortality = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_min.append(year)
    min_list_infant_mortality.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_infant_mortality}

oceania_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# ### Median

# %% [markdown]
# #### All countries

# %%
years_list_median = []
median_list_infant_deaths = []
for year in range(2000, 2016):
    median = np.median((life_expectancy['infant_deaths'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_median.append(year)
    median_list_infant_deaths.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_infant_deaths}

all_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### African region

# %%
years_list_median = []
median_list_infant_mortality = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_median.append(year)
    median_list_infant_mortality.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_infant_mortality}

african_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_median = []
median_list_infant_mortality = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_median.append(year)
    median_list_infant_mortality.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_infant_mortality}

asian_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### American region

# %%
years_list_median= []
median_list_infant_mortality = []
for year in range(2000, 2016):
    median= np.median(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_median.append(year)
    median_list_infant_mortality.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_infant_mortality}

american_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### European region

# %%
years_list_median = []
median_list_infant_mortality = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_median.append(year)
    median_list_infant_mortality.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_infant_mortality}

european_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_median = []
median_list_infant_mortality = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_median.append(year)
    median_list_infant_mortality.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_infant_mortality}

oceania_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# ### Standard Deviation

# %% [markdown]
# #### All countries

# %%
years_list_std = []
std_list = []
for year in range(2000, 2016):
    std = np.std((life_expectancy['infant_deaths'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_std.append(year)
    std_list.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list}

id_all_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### African region

# %%
years_list_std = []
std_list_infant_deaths = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_std.append(year)
    std_list_infant_deaths.append(round(std, 2))
african_std_dict = {'year': years_list_std, 'std': std_list_infant_deaths}

id_african_std_df = pd.DataFrame(african_std_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_std = []
std_list_infant_deaths = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_std.append(year)
    std_list_infant_deaths.append(round(std, 2))
asian_std_dict = {'year': years_list_std, 'std': std_list_infant_deaths}

id_asian_std_df = pd.DataFrame(asian_std_dict)

# %% [markdown]
# #### American region

# %%
years_list_std = []
std_list_infant_deaths = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_std.append(year)
    std_list_infant_deaths.append(round(std, 2))
american_std_dict = {'year': years_list_std, 'std': std_list_infant_deaths}

id_american_std_df = pd.DataFrame(american_std_dict)

# %% [markdown]
# #### European region

# %%
years_list_std = []
std_list_infant_deaths = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_std.append(year)
    std_list_infant_deaths.append(round(std, 2))
europe_std_dict = {'year': years_list_std, 'std': std_list_infant_deaths}

id_european_std_df = pd.DataFrame(europe_std_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_std = []
std_list_infant_deaths = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['life_expectancy'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_std.append(year)
    std_list_infant_deaths.append(round(std, 2))
oceania_std_dict = {'year': years_list_std, 'std': std_list_infant_deaths}

id_oceania_std_df = pd.DataFrame(oceania_std_dict)

# %% [markdown]
# ### Inter-Quartile Range

# %% [markdown]
# #### All countries

# %%
years_list_iqr = []
iqr_list = []
iqr_q1_list_infant_deaths = []
iqr_q3_list_infant_deaths = []
for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['infant_deaths'][life_expectancy['year'] == year], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list.append(round(iqr, 2))
    iqr_q1_list_infant_deaths.append(round(q1, 2))
    iqr_q3_list_infant_deaths.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_infant_deaths, '75%': iqr_q3_list_infant_deaths, 'iqr': iqr_list}

id_all_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### African region

# %%
years_list_iqr = []
iqr_list_infant_deaths = []
iqr_q1_list_infant_deaths = []
iqr_q3_list_infant_deaths = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_infant_deaths.append(round(iqr, 2))
    iqr_q1_list_infant_deaths.append(round(q1, 2))
    iqr_q3_list_infant_deaths.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_infant_deaths, '75%': iqr_q3_list_infant_deaths, 'iqr': iqr_list_infant_deaths}

id_african_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_iqr = []
iqr_list_infant_deaths = []
iqr_q1_list_infant_deaths = []
iqr_q3_list_infant_deaths = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_infant_deaths.append(round(iqr, 2))
    iqr_q1_list_infant_deaths.append(round(q1, 2))
    iqr_q3_list_infant_deaths.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_infant_deaths, '75%': iqr_q3_list_infant_deaths, 'iqr': iqr_list_infant_deaths}

id_asian_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### American region

# %%
years_list_iqr = []
iqr_list_infant_deaths = []
iqr_q1_list_infant_deaths = []
iqr_q3_list_infant_deaths = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_infant_deaths.append(round(iqr, 2))
    iqr_q1_list_infant_deaths.append(round(q1, 2))
    iqr_q3_list_infant_deaths.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_infant_deaths, '75%': iqr_q3_list_infant_deaths, 'iqr': iqr_list_infant_deaths}

id_american_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### European region

# %%
years_list_iqr = []
iqr_list_infant_deaths = []
iqr_q1_list_infant_deaths = []
iqr_q3_list_infant_deaths = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_infant_deaths.append(round(iqr, 2))
    iqr_q1_list_infant_deaths.append(round(q1, 2))
    iqr_q3_list_infant_deaths.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_infant_deaths, '75%': iqr_q3_list_infant_deaths, 'iqr': iqr_list_infant_deaths}

id_european_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_iqr = []
iqr_list_infant_deaths = []
iqr_q1_list_infant_deaths = []
iqr_q3_list_infant_deaths = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['infant_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_infant_deaths.append(round(iqr, 2))
    iqr_q1_list_infant_deaths.append(round(q1, 2))
    iqr_q3_list_infant_deaths.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_infant_deaths, '75%': iqr_q3_list_infant_deaths, 'iqr': iqr_list_infant_deaths}

id_oceania_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# ### Combining stats into single dataframe and converting it into a csv file

# %%
# Al countries
descriptive_stats_infant_deaths =all_means_df.merge(all_max_df, on='year').merge(all_min_df, on='year').merge(all_median_df, on='year').merge(id_all_std_df, on='year').merge(id_all_iqr_df, on='year')
descriptive_stats_infant_deaths.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_All_Dfs/Descriptive_Stats_All_infant_deaths.csv')

# Africa
descriptive_stats_infant_deaths_africa =african_mean_df.merge(african_max_df, on='year').merge(african_min_df, on='year').merge(african_median_df, on='year').merge(id_african_std_df, on='year').merge(id_african_iqr_df, on='year')
descriptive_stats_infant_deaths_africa.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/infant_deaths/Descriptive_Stats_Africa_infant_deaths.csv')

# Asia
descriptive_stats_infant_deaths_asia =asian_mean_df.merge(asian_max_df, on='year').merge(asian_min_df, on='year').merge(asian_median_df, on='year').merge(id_asian_std_df, on='year').merge(id_asian_iqr_df, on='year')
descriptive_stats_infant_deaths_asia.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/infant_deaths/Descriptive_Stats_Asia_infant_deaths.csv')

# America
descriptive_stats_infant_deaths_america =american_mean_df.merge(american_max_df, on='year').merge(american_min_df, on='year').merge(american_median_df, on='year').merge(id_american_std_df, on='year').merge(id_american_iqr_df, on='year')
descriptive_stats_infant_deaths_america.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/infant_deaths/Descriptive_Stats_America_infant_deaths.csv')

# Europe
descriptive_stats_infant_deaths_europe =european_mean_df.merge(european_max_df, on='year').merge(european_min_df, on='year').merge(european_median_df, on='year').merge(id_european_std_df, on='year').merge(id_european_iqr_df, on='year')
descriptive_stats_infant_deaths_europe.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/infant_deaths/Descriptive_Stats_Europe_infant_deaths.csv')

# Oceania
descriptive_stats_infant_deaths_oceania =oceania_mean_df.merge(oceania_max_df, on='year').merge(oceania_min_df, on='year').merge(oceania_median_df, on='year').merge(id_oceania_std_df, on='year').merge(id_oceania_iqr_df, on='year')
descriptive_stats_infant_deaths_oceania.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/infant_deaths/Descriptive_Stats_Oceania_infant_deaths.csv')

# %% [markdown]
# ## GDP per Capita

# %% [markdown]
# ### Mean

# %% [markdown]
# #### Al countries

# %%
years_list_mean = []
means_list_gdp_per_capita = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['gdp_per_capita'].where(life_expectancy.year == year))
    years_list_mean.append(year)
    means_list_gdp_per_capita.append(np.round(mean, 2))
all_means_dict = {'year': years_list_mean, 'mean': means_list_gdp_per_capita}

all_means_df = pd.DataFrame(all_means_dict)

# %% [markdown]
# #### African region

# %%
years_list_mean = []
mean_list_gdp_per_capita = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_mean.append(year)
    mean_list_gdp_per_capita.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_gdp_per_capita}

african_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_mean = []
mean_list_gdp_per_capita = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_mean.append(year)
    mean_list_gdp_per_capita.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_gdp_per_capita}

asian_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### American region

# %%
years_list_mean= []
mean_list_gdp_per_capita = []
for year in range(2000, 2016):
    mean= np.mean(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_mean.append(year)
    mean_list_gdp_per_capita.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_gdp_per_capita}

american_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### European region

# %%
years_list_mean = []
mean_list_gdp_per_capita = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_mean.append(year)
    mean_list_gdp_per_capita.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_gdp_per_capita}

european_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_mean = []
mean_list_gdp_per_capita = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_mean.append(year)
    mean_list_gdp_per_capita.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_gdp_per_capita}

oceania_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# ### Max

# %% [markdown]
# #### Al countries

# %%
years_list_max = []
max_list_gdp = []
max_countries_gdp = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['gdp_per_capita'][life_expectancy.year == year])
    max_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['gdp_per_capita'] == max)].values[0]
    years_list_max.append(year)
    max_list_gdp.append(max)
    max_countries_gdp.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list_gdp, 'max_countries': max_countries_gdp}

all_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### African region

# %%
years_list_max = []
max_list_gdp_per_capita = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_max.append(year)
    max_list_gdp_per_capita.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_gdp_per_capita}

african_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_max = []
max_list_gdp_per_capita = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_max.append(year)
    max_list_gdp_per_capita.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_gdp_per_capita}

asian_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### American region

# %%
years_list_max= []
max_list_gdp_per_capita = []
for year in range(2000, 2016):
    max= np.max(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_max.append(year)
    max_list_gdp_per_capita.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_gdp_per_capita}

american_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### European region

# %%
years_list_max = []
max_list_gdp_per_capita = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_max.append(year)
    max_list_gdp_per_capita.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_gdp_per_capita}

european_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_max = []
max_list_gdp_per_capita = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_max.append(year)
    max_list_gdp_per_capita.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_gdp_per_capita}

oceania_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# ### Minimum

# %% [markdown]
# #### All countries

# %%
years_list_min = []
min_list_gdp = []
min_countries_gdp = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['gdp_per_capita'].where(life_expectancy.year == year))
    min_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['gdp_per_capita'] == min)].values[0]
    years_list_min.append(year)
    min_list_gdp.append(min)
    min_countries_gdp.append(min_country)
all_min_dict = {'year': years_list_min, 'minimum': min_list_gdp, 'min_countries' : min_countries_gdp}

all_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### African region

# %%
years_list_min = []
min_list_gdp_per_capita = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_min.append(year)
    min_list_gdp_per_capita.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_gdp_per_capita}

african_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_min = []
min_list_gdp_per_capita = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_min.append(year)
    min_list_gdp_per_capita.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_gdp_per_capita}

asian_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### American region

# %%
years_list_min= []
min_list_gdp_per_capita = []
for year in range(2000, 2016):
    min= np.min(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_min.append(year)
    min_list_gdp_per_capita.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_gdp_per_capita}

american_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### European region

# %%
years_list_min = []
min_list_gdp_per_capita = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_min.append(year)
    min_list_gdp_per_capita.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_gdp_per_capita}

european_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_min = []
min_list_gdp_per_capita = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_min.append(year)
    min_list_gdp_per_capita.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_gdp_per_capita}

oceania_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# ### Median

# %% [markdown]
# #### All countries

# %%
years_list_median = []
median_list_gdp = []
for year in range(2000, 2016):
    median = np.median((life_expectancy['gdp_per_capita'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_median.append(year)
    median_list_gdp.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_gdp}

all_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### African region

# %%
years_list_median = []
median_list_gdp_per_capita = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_median.append(year)
    median_list_gdp_per_capita.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_gdp_per_capita}

african_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_median = []
median_list_gdp_per_capita = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_median.append(year)
    median_list_gdp_per_capita.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_gdp_per_capita}

asian_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### American region

# %%
years_list_median= []
median_list_gdp_per_capita = []
for year in range(2000, 2016):
    median= np.median(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_median.append(year)
    median_list_gdp_per_capita.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_gdp_per_capita}

american_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### European region

# %%
years_list_median = []
median_list_gdp_per_capita = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_median.append(year)
    median_list_gdp_per_capita.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_gdp_per_capita}

european_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_median = []
median_list_gdp_per_capita = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_median.append(year)
    median_list_gdp_per_capita.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_gdp_per_capita}

oceania_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# ### Standard Deviation

# %% [markdown]
# #### All countries

# %%
years_list_std = []
std_list = []
for year in range(2000, 2016):
    std = np.std((life_expectancy['gdp_per_capita'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_std.append(year)
    std_list.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list}

all_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### African region

# %%
years_list_std = []
std_list_gdp_per_capita = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_std.append(year)
    std_list_gdp_per_capita.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_gdp_per_capita}

african_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_std = []
std_list_gdp_per_capita = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_std.append(year)
    std_list_gdp_per_capita.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_gdp_per_capita}

asian_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### American region

# %%
years_list_std= []
std_list_gdp_per_capita = []
for year in range(2000, 2016):
    std= np.std(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_std.append(year)
    std_list_gdp_per_capita.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_gdp_per_capita}

american_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### European region

# %%
years_list_std = []
std_list_gdp_per_capita = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_std.append(year)
    std_list_gdp_per_capita.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_gdp_per_capita}

european_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_std = []
std_list_gdp_per_capita = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_std.append(year)
    std_list_gdp_per_capita.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_gdp_per_capita}

oceania_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# ### Inter-Quartile Range

# %% [markdown]
# #### All countries

# %%
years_list_iqr = []
iqr_list = []
iqr_q1_list_gdp_per_capita = []
iqr_q3_list_gdp_per_capita = []
for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['gdp_per_capita'][life_expectancy['year'] == year], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list.append(round(iqr, 2))
    iqr_q1_list_gdp_per_capita.append(round(q1, 2))
    iqr_q3_list_gdp_per_capita.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_gdp_per_capita, '75%': iqr_q3_list_gdp_per_capita, 'iqr': iqr_list}

gdp_all_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### African region

# %%
years_list_iqr = []
iqr_list_gdp_per_capita = []
iqr_q1_list_gdp_per_capita = []
iqr_q3_list_gdp_per_capita = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_gdp_per_capita.append(round(iqr, 2))
    iqr_q1_list_gdp_per_capita.append(round(q1, 2))
    iqr_q3_list_gdp_per_capita.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_gdp_per_capita, '75%': iqr_q3_list_gdp_per_capita, 'iqr': iqr_list_gdp_per_capita}

gdp_african_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_iqr = []
iqr_list_gdp_per_capita = []
iqr_q1_list_gdp_per_capita = []
iqr_q3_list_gdp_per_capita = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_gdp_per_capita.append(round(iqr, 2))
    iqr_q1_list_gdp_per_capita.append(round(q1, 2))
    iqr_q3_list_gdp_per_capita.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_gdp_per_capita, '75%': iqr_q3_list_gdp_per_capita, 'iqr': iqr_list_gdp_per_capita}

gdp_asian_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### American region

# %%
years_list_iqr = []
iqr_list_gdp_per_capita = []
iqr_q1_list_gdp_per_capita = []
iqr_q3_list_gdp_per_capita = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_gdp_per_capita.append(round(iqr, 2))
    iqr_q1_list_gdp_per_capita.append(round(q1, 2))
    iqr_q3_list_gdp_per_capita.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_gdp_per_capita, '75%': iqr_q3_list_gdp_per_capita, 'iqr': iqr_list_gdp_per_capita}

gdp_american_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### European region

# %%
years_list_iqr = []
iqr_list_gdp_per_capita = []
iqr_q1_list_gdp_per_capita = []
iqr_q3_list_gdp_per_capita = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_gdp_per_capita.append(round(iqr, 2))
    iqr_q1_list_gdp_per_capita.append(round(q1, 2))
    iqr_q3_list_gdp_per_capita.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_gdp_per_capita, '75%': iqr_q3_list_gdp_per_capita, 'iqr': iqr_list_gdp_per_capita}

gdp_european_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_iqr = []
iqr_list_gdp_per_capita = []
iqr_q1_list_gdp_per_capita = []
iqr_q3_list_gdp_per_capita = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['gdp_per_capita'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_gdp_per_capita.append(round(iqr, 2))
    iqr_q1_list_gdp_per_capita.append(round(q1, 2))
    iqr_q3_list_gdp_per_capita.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_gdp_per_capita, '75%': iqr_q3_list_gdp_per_capita, 'iqr': iqr_list_gdp_per_capita}

gdp_oceania_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# ### Combining stats into single dataframe and converting it into a csv file

# %%
# Al countries
descriptive_stats_gdp_per_capita =all_means_df.merge(all_max_df, on='year').merge(all_min_df, on='year').merge(all_median_df, on='year').merge(all_std_df, on='year').merge(gdp_all_iqr_df, on='year')
descriptive_stats_gdp_per_capita.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_All_Dfs/Descriptive_stats_GDP_per_capita.csv')

# Africa
descriptive_stats_gdp_per_capita_africa =african_mean_df.merge(african_max_df, on='year').merge(african_min_df, on='year').merge(african_median_df, on='year').merge(african_std_df, on='year').merge(gdp_african_iqr_df, on='year')
descriptive_stats_gdp_per_capita_africa.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/GDP/Descriptive_Stats_Africa_gdp_per_capita.csv')

# Asia
descriptive_stats_gdp_per_capita_asia =asian_mean_df.merge(asian_max_df, on='year').merge(asian_min_df, on='year').merge(asian_median_df, on='year').merge(asian_std_df, on='year').merge(gdp_asian_iqr_df, on='year')
descriptive_stats_gdp_per_capita_asia.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/GDP/Descriptive_Stats_Asia_gdp_per_capita.csv')

# America
descriptive_stats_gdp_per_capita_america =american_mean_df.merge(american_max_df, on='year').merge(american_min_df, on='year').merge(american_median_df, on='year').merge(american_std_df, on='year').merge(gdp_american_iqr_df, on='year')
descriptive_stats_gdp_per_capita_america.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/GDP/Descriptive_Stats_America_gdp_per_capita.csv')

# Europe
descriptive_stats_gdp_per_capita_europe =european_mean_df.merge(european_max_df, on='year').merge(european_min_df, on='year').merge(european_median_df, on='year').merge(european_std_df, on='year').merge(gdp_european_iqr_df, on='year')
descriptive_stats_gdp_per_capita_europe.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/GDP/Descriptive_Stats_Europe_gdp_per_capita.csv')

# Oceania
descriptive_stats_gdp_per_capita_oceania =oceania_mean_df.merge(oceania_max_df, on='year').merge(oceania_min_df, on='year').merge(oceania_median_df, on='year').merge(oceania_std_df, on='year').merge(gdp_oceania_iqr_df, on='year')
descriptive_stats_gdp_per_capita_oceania.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/GDP/Descriptive_Stats_Oceania_gdp_per_capita.csv')

# %% [markdown]
# ## Under Five Deaths

# %% [markdown]
# ### Mean

# %% [markdown]
# #### Al countries

# %%
years_list_mean = []
means_list_u5_deaths = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['under_five_deaths'].where(life_expectancy.year == year))
    years_list_mean.append(year)
    means_list_u5_deaths.append(np.round(mean, 2))
all_means_dict = {'year': years_list_mean, 'mean': means_list_u5_deaths}

all_means_df = pd.DataFrame(all_means_dict)

# %% [markdown]
# #### African region

# %%
years_list_mean = []
mean_list_u5_deaths = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_mean.append(year)
    mean_list_u5_deaths.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_u5_deaths}

african_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_mean = []
mean_list_u5_deaths = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_mean.append(year)
    mean_list_u5_deaths.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_u5_deaths}

asian_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### American region

# %%
years_list_mean= []
mean_list_u5_deaths = []
for year in range(2000, 2016):
    mean= np.mean(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_mean.append(year)
    mean_list_u5_deaths.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_u5_deaths}

american_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### European region

# %%
years_list_mean = []
mean_list_u5_deaths = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_mean.append(year)
    mean_list_u5_deaths.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_u5_deaths}

european_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_mean = []
mean_list_u5_deaths = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_mean.append(year)
    mean_list_u5_deaths.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_u5_deaths}

oceania_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# ### Max

# %% [markdown]
# #### Al countries

# %%
years_list_max = []
max_list_u5_deaths = []
max_countries_u5_deaths = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['under_five_deaths'][life_expectancy.year == year])
    max_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['under_five_deaths'] == max)].values[0]
    years_list_max.append(year)
    max_list_u5_deaths.append(max)
    max_countries_u5_deaths.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list_u5_deaths, 'max_countries': max_countries_u5_deaths}

all_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### African region

# %%
years_list_max = []
max_list_u5_deaths = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_max.append(year)
    max_list_u5_deaths.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_u5_deaths}

african_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_max = []
max_list_u5_deaths = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_max.append(year)
    max_list_u5_deaths.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_u5_deaths}

asian_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### American region

# %%
years_list_max= []
max_list_u5_deaths = []
for year in range(2000, 2016):
    max= np.max(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_max.append(year)
    max_list_u5_deaths.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_u5_deaths}

american_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### European region

# %%
years_list_max = []
max_list_u5_deaths = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_max.append(year)
    max_list_u5_deaths.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_u5_deaths}

european_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_max = []
max_list_u5_deaths = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_max.append(year)
    max_list_u5_deaths.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_u5_deaths}

oceania_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# ### Minimum

# %% [markdown]
# #### All countries

# %%
years_list_min = []
min_list_under_five_deaths = []
min_countries_under_five_deaths = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['under_five_deaths'].where(life_expectancy.year == year))
    min_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['under_five_deaths'] == min)].values[0]
    years_list_min.append(year)
    min_list_under_five_deaths.append(min)
    min_countries_under_five_deaths.append(min_country)
all_min_dict = {'year': years_list_min, 'minimum': min_list_under_five_deaths, 'min_countries' : min_countries_under_five_deaths}

all_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### African region

# %%
years_list_min = []
min_list_under_five_deaths = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_min.append(year)
    min_list_under_five_deaths.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_under_five_deaths}

african_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_min = []
min_list_under_five_deaths = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_min.append(year)
    min_list_under_five_deaths.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_under_five_deaths}

asian_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### American region

# %%
years_list_min= []
min_list_under_five_deaths = []
for year in range(2000, 2016):
    min= np.min(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_min.append(year)
    min_list_under_five_deaths.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_under_five_deaths}

american_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### European region

# %%
years_list_min = []
min_list_under_five_deaths = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_min.append(year)
    min_list_under_five_deaths.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_under_five_deaths}

european_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_min = []
min_list_under_five_deaths = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_min.append(year)
    min_list_under_five_deaths.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_under_five_deaths}

oceania_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# ### Median

# %% [markdown]
# #### All countries

# %%
years_list_median = []
median_list_under_five_deaths = []
for year in range(2000, 2016):
    median = np.median((life_expectancy['under_five_deaths'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_median.append(year)
    median_list_under_five_deaths.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_under_five_deaths}

all_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### African region

# %%
years_list_median = []
median_list_under_five_deaths = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_median.append(year)
    median_list_under_five_deaths.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_under_five_deaths}

african_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_median = []
median_list_under_five_deaths = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_median.append(year)
    median_list_under_five_deaths.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_under_five_deaths}

asian_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### American region

# %%
years_list_median= []
median_list_under_five_deaths = []
for year in range(2000, 2016):
    median= np.median(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_median.append(year)
    median_list_under_five_deaths.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_under_five_deaths}

american_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### European region

# %%
years_list_median = []
median_list_under_five_deaths = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_median.append(year)
    median_list_under_five_deaths.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_under_five_deaths}

european_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_median = []
median_list_under_five_deaths = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_median.append(year)
    median_list_under_five_deaths.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_under_five_deaths}

oceania_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# ### Standard Deviation

# %% [markdown]
# #### All countries

# %%
years_list_std = []
std_list = []
for year in range(2000, 2016):
    std = np.std((life_expectancy['under_five_deaths'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_std.append(year)
    std_list.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list}

all_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### African region

# %%
years_list_std = []
std_list_under_five_deaths = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_std.append(year)
    std_list_under_five_deaths.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_under_five_deaths}

african_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_std = []
std_list_under_five_deaths = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_std.append(year)
    std_list_under_five_deaths.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_under_five_deaths}

asian_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### American region

# %%
years_list_std= []
std_list_under_five_deaths = []
for year in range(2000, 2016):
    std= np.std(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_std.append(year)
    std_list_under_five_deaths.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_under_five_deaths}

american_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### European region

# %%
years_list_std = []
std_list_under_five_deaths = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_std.append(year)
    std_list_under_five_deaths.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_under_five_deaths}

european_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_std = []
std_list_under_five_deaths = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_std.append(year)
    std_list_under_five_deaths.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_under_five_deaths}

oceania_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# ### Inter-Quartile Range

# %% [markdown]
# #### All countries

# %%
years_list_iqr = []
iqr_list = []
iqr_q1_list_under_five_deaths = []
iqr_q3_list_under_five_deaths = []
for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['under_five_deaths'][life_expectancy['year'] == year], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list.append(round(iqr, 2))
    iqr_q1_list_under_five_deaths.append(round(q1, 2))
    iqr_q3_list_under_five_deaths.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_under_five_deaths, '75%': iqr_q3_list_under_five_deaths, 'iqr': iqr_list}

u5d_all_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### African region

# %%
years_list_iqr = []
iqr_list_under_five_deaths = []
iqr_q1_list_under_five_deaths = []
iqr_q3_list_under_five_deaths = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_under_five_deaths.append(round(iqr, 2))
    iqr_q1_list_under_five_deaths.append(round(q1, 2))
    iqr_q3_list_under_five_deaths.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_under_five_deaths, '75%': iqr_q3_list_under_five_deaths, 'iqr': iqr_list_under_five_deaths}

u5d_african_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_iqr = []
iqr_list_under_five_deaths = []
iqr_q1_list_under_five_deaths = []
iqr_q3_list_under_five_deaths = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_under_five_deaths.append(round(iqr, 2))
    iqr_q1_list_under_five_deaths.append(round(q1, 2))
    iqr_q3_list_under_five_deaths.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_under_five_deaths, '75%': iqr_q3_list_under_five_deaths, 'iqr': iqr_list_under_five_deaths}

u5d_asian_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### American region

# %%
years_list_iqr = []
iqr_list_under_five_deaths = []
iqr_q1_list_under_five_deaths = []
iqr_q3_list_under_five_deaths = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_under_five_deaths.append(round(iqr, 2))
    iqr_q1_list_under_five_deaths.append(round(q1, 2))
    iqr_q3_list_under_five_deaths.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_under_five_deaths, '75%': iqr_q3_list_under_five_deaths, 'iqr': iqr_list_under_five_deaths}

u5d_american_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### European region

# %%
years_list_iqr = []
iqr_list_under_five_deaths = []
iqr_q1_list_under_five_deaths = []
iqr_q3_list_under_five_deaths = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_under_five_deaths.append(round(iqr, 2))
    iqr_q1_list_under_five_deaths.append(round(q1, 2))
    iqr_q3_list_under_five_deaths.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_under_five_deaths, '75%': iqr_q3_list_under_five_deaths, 'iqr': iqr_list_under_five_deaths}

u5d_european_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_iqr = []
iqr_list_under_five_deaths = []
iqr_q1_list_under_five_deaths = []
iqr_q3_list_under_five_deaths = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['under_five_deaths'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_under_five_deaths.append(round(iqr, 2))
    iqr_q1_list_under_five_deaths.append(round(q1, 2))
    iqr_q3_list_under_five_deaths.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_under_five_deaths, '75%': iqr_q3_list_under_five_deaths, 'iqr': iqr_list_under_five_deaths}

u5d_oceania_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# ### Combining stats into single dataframe and converting it into a csv file

# %%
# Al countries
descriptive_stats_under_five_deaths =all_means_df.merge(all_max_df, on='year').merge(all_min_df, on='year').merge(all_median_df, on='year').merge(all_std_df, on='year').merge(u5d_all_iqr_df, on='year')
descriptive_stats_under_five_deaths.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_All_Dfs/Descriptive_Stats_All_under_five_deaths.csv')

# Africa
descriptive_stats_under_five_deaths_africa =african_mean_df.merge(african_max_df, on='year').merge(african_min_df, on='year').merge(african_median_df, on='year').merge(african_std_df, on='year').merge(u5d_african_iqr_df, on='year')
descriptive_stats_under_five_deaths_africa.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Under_Five_Deaths/Descriptive_Stats_Africa_under_five_deaths.csv')

# Asia
descriptive_stats_under_five_deaths_asia =asian_mean_df.merge(asian_max_df, on='year').merge(asian_min_df, on='year').merge(asian_median_df, on='year').merge(asian_std_df, on='year').merge(u5d_asian_iqr_df, on='year')
descriptive_stats_under_five_deaths_asia.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Under_Five_Deaths/Descriptive_Stats_Asia_under_five_deaths.csv')

# America
descriptive_stats_under_five_deaths_america =american_mean_df.merge(american_max_df, on='year').merge(american_min_df, on='year').merge(american_median_df, on='year').merge(american_std_df, on='year').merge(u5d_american_iqr_df, on='year')
descriptive_stats_under_five_deaths_america.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Under_Five_Deaths/Descriptive_Stats_America_under_five_deaths.csv')

# Europe
descriptive_stats_under_five_deaths_europe =european_mean_df.merge(european_max_df, on='year').merge(european_min_df, on='year').merge(european_median_df, on='year').merge(european_std_df, on='year').merge(u5d_european_iqr_df, on='year')
descriptive_stats_under_five_deaths_europe.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Under_Five_Deaths/Descriptive_Stats_Europe_under_five_deaths.csv')

# Oceania
descriptive_stats_under_five_deaths_oceania =oceania_mean_df.merge(oceania_max_df, on='year').merge(oceania_min_df, on='year').merge(oceania_median_df, on='year').merge(oceania_std_df, on='year').merge(u5d_oceania_iqr_df, on='year')
descriptive_stats_under_five_deaths_oceania.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Under_Five_Deaths/Descriptive_Stats_Oceania_under_five_deaths.csv')

# %% [markdown]
# ## BMI Male

# %% [markdown]
# ### Mean

# %% [markdown]
# #### Al countries

# %%
years_list_mean = []
means_list_bmi_male = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['bmi_male'].where(life_expectancy.year == year))
    years_list_mean.append(year)
    means_list_bmi_male.append(np.round(mean, 2))
all_means_dict = {'year': years_list_mean, 'mean': means_list_bmi_male}

all_means_df = pd.DataFrame(all_means_dict)

# %% [markdown]
# #### African region

# %%
years_list_mean = []
mean_list_bmi_male = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_mean.append(year)
    mean_list_bmi_male.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_bmi_male}

african_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_mean = []
mean_list_bmi_male = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_mean.append(year)
    mean_list_bmi_male.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_bmi_male}

asian_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### American region

# %%
years_list_mean= []
mean_list_bmi_male = []
for year in range(2000, 2016):
    mean= np.mean(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_mean.append(year)
    mean_list_bmi_male.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_bmi_male}

american_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### European region

# %%
years_list_mean = []
mean_list_bmi_male = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_mean.append(year)
    mean_list_bmi_male.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_bmi_male}

european_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_mean = []
mean_list_bmi_male = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_mean.append(year)
    mean_list_bmi_male.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_bmi_male}

oceania_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# ### Max

# %% [markdown]
# #### Al countries

# %%
years_list_max = []
max_list_bmi_male = []
max_countries_bmi_male = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['bmi_male'][life_expectancy.year == year])
    max_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['bmi_male'] == max)].values[0]
    years_list_max.append(year)
    max_list_bmi_male.append(max)
    max_countries_bmi_male.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list_bmi_male, 'max_countries': max_countries_bmi_male}

all_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### African region

# %%
years_list_max = []
max_list_bmi_male = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_max.append(year)
    max_list_bmi_male.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_bmi_male}

african_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_max = []
max_list_bmi_male = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_max.append(year)
    max_list_bmi_male.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_bmi_male}

asian_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### American region

# %%
years_list_max= []
max_list_bmi_male = []
for year in range(2000, 2016):
    max= np.max(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_max.append(year)
    max_list_bmi_male.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_bmi_male}

american_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### European region

# %%
years_list_max = []
max_list_bmi_male = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_max.append(year)
    max_list_bmi_male.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_bmi_male}

european_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_max = []
max_list_bmi_male = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_max.append(year)
    max_list_bmi_male.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_bmi_male}

oceania_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# ### Minimum

# %% [markdown]
# #### All countries

# %%
years_list_min = []
min_list_bmi_male = []
min_countries_bmi_male = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['bmi_male'].where(life_expectancy.year == year))
    min_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['bmi_male'] == min)].values[0]
    years_list_min.append(year)
    min_list_bmi_male.append(min)
    min_countries_bmi_male.append(min_country)
all_min_dict = {'year': years_list_min, 'minimum': min_list_bmi_male, 'min_countries' : min_countries_bmi_male}

all_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### African region

# %%
years_list_min = []
min_list_bmi_male = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_min.append(year)
    min_list_bmi_male.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_bmi_male}

african_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_min = []
min_list_bmi_male = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_min.append(year)
    min_list_bmi_male.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_bmi_male}

asian_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### American region

# %%
years_list_min= []
min_list_bmi_male = []
for year in range(2000, 2016):
    min= np.min(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_min.append(year)
    min_list_bmi_male.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_bmi_male}

american_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### European region

# %%
years_list_min = []
min_list_bmi_male= []
for year in range(2000, 2016):
    min = np.min(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_min.append(year)
    min_list_bmi_male.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_bmi_male}

european_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_min = []
min_list_bmi_male = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_min.append(year)
    min_list_bmi_male.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_bmi_male}

oceania_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# ### Median

# %% [markdown]
# #### All countries

# %%
years_list_median = []
median_list_bmi_male = []
for year in range(2000, 2016):
    median = np.median((life_expectancy['bmi_male'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_median.append(year)
    median_list_bmi_male.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_bmi_male}

all_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### African region

# %%
years_list_median = []
median_list_bmi_male = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_median.append(year)
    median_list_bmi_male.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_bmi_male}

african_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_median = []
median_list_bmi_male = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_median.append(year)
    median_list_bmi_male.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_bmi_male}

asian_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### American region

# %%
years_list_median= []
median_list_bmi_male = []
for year in range(2000, 2016):
    median= np.median(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_median.append(year)
    median_list_bmi_male.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_bmi_male}

american_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### European region

# %%
years_list_median = []
median_list_bmi_male = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_median.append(year)
    median_list_bmi_male.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_bmi_male}

european_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_median = []
median_list_bmi_male = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_median.append(year)
    median_list_bmi_male.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_bmi_male}

oceania_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# ### Standard Deviation

# %% [markdown]
# #### All countries

# %%
years_list_std = []
std_list = []
for year in range(2000, 2016):
    std = np.std((life_expectancy['bmi_male'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_std.append(year)
    std_list.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list}

all_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### African region

# %%
years_list_std = []
std_list_bmi_male = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_std.append(year)
    std_list_bmi_male.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_bmi_male}

african_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_std = []
std_list_bmi_male = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_std.append(year)
    std_list_bmi_male.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_bmi_male}

asian_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### American region

# %%
years_list_std= []
std_list_bmi_male = []
for year in range(2000, 2016):
    std= np.std(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_std.append(year)
    std_list_bmi_male.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_bmi_male}

american_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### European region

# %%
years_list_std = []
std_list_bmi_male = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_std.append(year)
    std_list_bmi_male.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_bmi_male}

european_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_std = []
std_list_bmi_male = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_std.append(year)
    std_list_bmi_male.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_bmi_male}

oceania_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# ### Inter-Quartile Range

# %% [markdown]
# #### All countries

# %%
years_list_iqr = []
iqr_list = []
iqr_q1_list_bmi_male = []
iqr_q3_list_bmi_male = []
for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['bmi_male'][life_expectancy['year'] == year], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list.append(round(iqr, 2))
    iqr_q1_list_bmi_male.append(round(q1, 2))
    iqr_q3_list_bmi_male.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_bmi_male, '75%': iqr_q3_list_bmi_male, 'iqr': iqr_list}

bmim_all_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### African region

# %%
years_list_iqr = []
iqr_list_bmi_male = []
iqr_q1_list_bmi_male = []
iqr_q3_list_bmi_male = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_bmi_male.append(round(iqr, 2))
    iqr_q1_list_bmi_male.append(round(q1, 2))
    iqr_q3_list_bmi_male.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_bmi_male, '75%': iqr_q3_list_bmi_male, 'iqr': iqr_list_bmi_male}

bmim_african_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_iqr = []
iqr_list_bmi_male = []
iqr_q1_list_bmi_male = []
iqr_q3_list_bmi_male = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_bmi_male.append(round(iqr, 2))
    iqr_q1_list_bmi_male.append(round(q1, 2))
    iqr_q3_list_bmi_male.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_bmi_male, '75%': iqr_q3_list_bmi_male, 'iqr': iqr_list_bmi_male}

bmim_asian_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### American region

# %%
years_list_iqr = []
iqr_list_bmi_male = []
iqr_q1_list_bmi_male = []
iqr_q3_list_bmi_male = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_bmi_male.append(round(iqr, 2))
    iqr_q1_list_bmi_male.append(round(q1, 2))
    iqr_q3_list_bmi_male.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_bmi_male, '75%': iqr_q3_list_bmi_male, 'iqr': iqr_list_bmi_male}

bmim_american_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### European region

# %%
years_list_iqr = []
iqr_list_bmi_male = []
iqr_q1_list_bmi_male = []
iqr_q3_list_bmi_male = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_bmi_male.append(round(iqr, 2))
    iqr_q1_list_bmi_male.append(round(q1, 2))
    iqr_q3_list_bmi_male.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_bmi_male, '75%': iqr_q3_list_bmi_male, 'iqr': iqr_list_bmi_male}

bmim_european_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_iqr = []
iqr_list_bmi_male = []
iqr_q1_list_bmi_male = []
iqr_q3_list_bmi_male = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['bmi_male'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_bmi_male.append(round(iqr, 2))
    iqr_q1_list_bmi_male.append(round(q1, 2))
    iqr_q3_list_bmi_male.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_bmi_male, '75%': iqr_q3_list_bmi_male, 'iqr': iqr_list_bmi_male}

bmim_oceania_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# ### Combining stats into single dataframe and converting it into a csv file

# %%
# Al countries
descriptive_stats_adult_mortality =am_all_means_df.merge(am_all_max_df, on='year').merge(am_all_min_df, on='year').merge(am_all_median_df, on='year').merge(am_all_std_df, on='year').merge(am_all_std_df, on='year').merge(am_all_iqr_df, on='year')
descriptive_stats_adult_mortality.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_All_Dfs/Descriptive_Stats_All_Adult_Mortality.csv')

# Africa
descriptive_stats_adult_mortality_africa =am_african_mean_df.merge(am_african_max_df, on='year').merge(am_african_min_df, on='year').merge(am_african_median_df, on='year').merge(am_african_std_df, on='year').merge(am_african_iqr_df, on='year')
descriptive_stats_adult_mortality_africa.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Adult_Mortality/Descriptive_Stats_Africa_Adult_Mortality.csv')

# Asia
descriptive_stats_adult_mortality_asia =am_asian_mean_df.merge(am_asian_max_df, on='year').merge(am_asian_min_df, on='year').merge(am_asian_median_df, on='year').merge(am_asian_std_df, on='year').merge(am_asian_iqr_df, on='year')
descriptive_stats_adult_mortality_asia.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Adult_Mortality/Descriptive_Stats_Asia_Adult_Mortality.csv')

# America
descriptive_stats_adult_mortality_america = am_american_mean_df.merge(am_merican_max_df, on='year').merge(am_american_min_df, on='year').merge(am_american_median_df, on='year').merge(am_american_std_df, on='year').merge(am_american_iqr_df, on='year')
descriptive_stats_adult_mortality_america.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Adult_Mortality/Descriptive_Stats_America_Adult_Mortality.csv')

# Europe
descriptive_stats_adult_mortality_europe =am_european_mean_df.merge(am_european_max_df, on='year').merge(am_european_min_df, on='year').merge(am_european_median_df, on='year').merge(am_european_std_df, on='year').merge(am_european_iqr_df, on='year')
descriptive_stats_adult_mortality_europe.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Adult_Mortality/Descriptive_Stats_Europe_Adult_Mortality.csv')

# Oceania
descriptive_stats_adult_mortality_oceania =am_oceania_median_df.merge(am_oceania_max_df, on='year').merge(am_oceania_min_df, on='year').merge(am_oceania_median_df, on='year').merge(am_oceania_std_df, on='year').merge(am_oceania_iqr_df, on='year')
descriptive_stats_adult_mortality_oceania.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Adult_Mortality/Descriptive_Stats_Oceania_Adult_Mortality.csv')

# %% [markdown]
# ### Combining stats into single dataframe and converting it into a csv file

# %%
# Al countries
descriptive_stats_bmi_male =all_means_df.merge(all_max_df, on='year').merge(all_min_df, on='year').merge(all_median_df, on='year').merge(all_std_df, on='year').merge(am_all_iqr_df, on='year')
descriptive_stats_bmi_male.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_All_Dfs/Descriptive_Stats_All_bmi_male.csv')

# Africa
descriptive_stats_bmi_male_africa =african_mean_df.merge(african_max_df, on='year').merge(african_min_df, on='year').merge(african_median_df, on='year').merge(african_std_df, on='year').merge(bmim_african_iqr_df, on='year')
descriptive_stats_bmi_male_africa.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/BMI_Male/Descriptive_Stats_Africa_bmi_male.csv')

# Asia
descriptive_stats_bmi_male_asia =asian_mean_df.merge(asian_max_df, on='year').merge(asian_min_df, on='year').merge(asian_median_df, on='year').merge(asian_std_df, on='year').merge(bmim_asian_iqr_df, on='year')
descriptive_stats_bmi_male_asia.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/BMI_Male/Descriptive_Stats_Asia_bmi_male.csv')

# America
descriptive_stats_bmi_male_america =american_mean_df.merge(american_max_df, on='year').merge(american_min_df, on='year').merge(american_median_df, on='year').merge(american_std_df, on='year').merge(bmim_american_iqr_df, on='year')
descriptive_stats_bmi_male_america.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/BMI_Male/Descriptive_Stats_America_bmi_male.csv')

# Europe
descriptive_stats_bmi_male_europe =european_mean_df.merge(european_max_df, on='year').merge(european_min_df, on='year').merge(european_median_df, on='year').merge(european_std_df, on='year').merge(bmim_european_iqr_df, on='year')
descriptive_stats_bmi_male_europe.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/BMI_Male/Descriptive_Stats_Europe_bmi_male.csv')

# Oceania
descriptive_stats_bmi_male_oceania =oceania_mean_df.merge(oceania_max_df, on='year').merge(oceania_min_df, on='year').merge(oceania_median_df, on='year').merge(oceania_std_df, on='year').merge(bmim_oceania_iqr_df, on='year')
descriptive_stats_bmi_male_oceania.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/BMI_Male/Descriptive_Stats_Oceania_bmi_male.csv')

# %% [markdown]
# ## BMI Female

# %% [markdown]
# ### Mean

# %% [markdown]
# #### Al countries

# %%
years_list_mean = []
means_list_bmi_female = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['bmi_female'].where(life_expectancy.year == year))
    years_list_mean.append(year)
    means_list_bmi_female.append(np.round(mean, 2))
all_means_dict = {'year': years_list_mean, 'mean': means_list_bmi_female}

all_means_df = pd.DataFrame(all_means_dict)

# %% [markdown]
# #### African region

# %%
years_list_mean = []
mean_list_bmi_female = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_mean.append(year)
    mean_list_bmi_female.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_bmi_female}

african_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_mean = []
mean_list_bmi_female = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_mean.append(year)
    mean_list_bmi_female.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_bmi_female}

asian_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### American region

# %%
years_list_mean= []
mean_list_bmi_female = []
for year in range(2000, 2016):
    mean= np.mean(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_mean.append(year)
    mean_list_bmi_female.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_bmi_female}

american_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### European region

# %%
years_list_mean = []
mean_list_bmi_female = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_mean.append(year)
    mean_list_bmi_female.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_bmi_female}

european_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_mean = []
mean_list_bmi_female = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_mean.append(year)
    mean_list_bmi_female.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_bmi_female}

oceania_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# ### Max

# %% [markdown]
# #### Al countries

# %%
years_list_max = []
max_list_bmi_female = []
max_countries_bmi_female = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['bmi_female'][life_expectancy.year == year])
    max_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['bmi_female'] == max)].values[0]
    years_list_max.append(year)
    max_list_bmi_female.append(max)
    max_countries_bmi_female.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list_bmi_female, 'max_countries': max_countries_bmi_female}

all_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### African region

# %%
years_list_max = []
max_list_bmi_female = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_max.append(year)
    max_list_bmi_female.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_bmi_female}

african_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_max = []
max_list_bmi_female = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_max.append(year)
    max_list_bmi_female.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_bmi_female}

asian_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### American region

# %%
years_list_max= []
max_list_bmi_female = []
for year in range(2000, 2016):
    max= np.max(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_max.append(year)
    max_list_bmi_female.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_bmi_female}

american_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### European region

# %%
years_list_max = []
max_list_bmi_female = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_max.append(year)
    max_list_bmi_female.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_bmi_female}

european_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_max = []
max_list_bmi_female = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_max.append(year)
    max_list_bmi_female.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_bmi_female}

oceania_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# ### Minimum

# %% [markdown]
# #### All countries

# %%
years_list_min = []
min_list_bmi_female = []
min_countries_bmi_female = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['bmi_female'].where(life_expectancy.year == year))
    min_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['bmi_female'] == min)].values[0]
    years_list_min.append(year)
    min_list_bmi_female.append(min)
    min_countries_bmi_female.append(min_country)
all_min_dict = {'year': years_list_min, 'minimum': min_list_bmi_female, 'min_countries' : min_countries_bmi_female}

all_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### African region

# %%
years_list_min = []
min_list_bmi_female = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_min.append(year)
    min_list_bmi_female.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_bmi_female}

african_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_min = []
min_list_bmi_female = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_min.append(year)
    min_list_bmi_female.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_bmi_female}

asian_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### American region

# %%
years_list_min= []
min_list_bmi_female = []
for year in range(2000, 2016):
    min= np.min(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_min.append(year)
    min_list_bmi_female.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_bmi_female}

american_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### European region

# %%
years_list_min = []
min_list_bmi_female= []
for year in range(2000, 2016):
    min = np.min(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_min.append(year)
    min_list_bmi_female.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_bmi_female}

european_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_min = []
min_list_bmi_female = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_min.append(year)
    min_list_bmi_female.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_bmi_female}

oceania_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# ### Median

# %% [markdown]
# #### All countries

# %%
years_list_mean = []
mean_list_bmi_female = []
for year in range(2000, 2016):
    mean = np.mean((life_expectancy['bmi_female'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_mean.append(year)
    mean_list_bmi_female.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_bmi_female}

all_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### African region

# %%
years_list_median = []
median_list_bmi_female = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_median.append(year)
    median_list_bmi_female.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_bmi_female}

african_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_median = []
median_list_bmi_female = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_median.append(year)
    median_list_bmi_female.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_bmi_female}

asian_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### American region

# %%
years_list_median= []
median_list_bmi_female = []
for year in range(2000, 2016):
    median= np.median(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_median.append(year)
    median_list_bmi_female.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_bmi_female}

american_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### European region

# %%
years_list_median = []
median_list_bmi_female = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_median.append(year)
    median_list_bmi_female.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_bmi_female}

european_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_median = []
median_list_bmi_female = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_median.append(year)
    median_list_bmi_female.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_bmi_female}

oceania_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# ### Standard Deviation

# %% [markdown]
# #### All countries

# %%
years_list_std = []
std_list = []
for year in range(2000, 2016):
    std = np.std((life_expectancy['bmi_female'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_std.append(year)
    std_list.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list}

all_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### African region

# %%
years_list_std = []
std_list_bmi_female = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_std.append(year)
    std_list_bmi_female.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_bmi_female}

african_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_std = []
std_list_bmi_female = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_std.append(year)
    std_list_bmi_female.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_bmi_female}

asian_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### American region

# %%
years_list_std= []
std_list_bmi_female = []
for year in range(2000, 2016):
    std= np.std(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_std.append(year)
    std_list_bmi_female.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_bmi_female}

american_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### European region

# %%
years_list_std = []
std_list_bmi_female = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_std.append(year)
    std_list_bmi_female.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_bmi_female}

european_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_std = []
std_list_bmi_female = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_std.append(year)
    std_list_bmi_female.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_bmi_female}

oceania_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# ### Inter-Quartile Range

# %% [markdown]
# #### All countries

# %%
years_list_iqr = []
iqr_list = []
iqr_q1_list_bmi_female = []
iqr_q3_list_bmi_female = []
for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['bmi_female'][life_expectancy['year'] == year], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list.append(round(iqr, 2))
    iqr_q1_list_bmi_female.append(round(q1, 2))
    iqr_q3_list_bmi_female.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_bmi_female, '75%': iqr_q3_list_bmi_female, 'iqr': iqr_list}

bmif_all_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### African region

# %%
years_list_iqr = []
iqr_list_bmi_female = []
iqr_q1_list_bmi_female = []
iqr_q3_list_bmi_female = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_bmi_female.append(round(iqr, 2))
    iqr_q1_list_bmi_female.append(round(q1, 2))
    iqr_q3_list_bmi_female.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_bmi_female, '75%': iqr_q3_list_bmi_female, 'iqr': iqr_list_bmi_female}

bmif_african_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_iqr = []
iqr_list_bmi_female = []
iqr_q1_list_bmi_female = []
iqr_q3_list_bmi_female = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_bmi_female.append(round(iqr, 2))
    iqr_q1_list_bmi_female.append(round(q1, 2))
    iqr_q3_list_bmi_female.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_bmi_female, '75%': iqr_q3_list_bmi_female, 'iqr': iqr_list_bmi_female}

bmif_asian_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### American region

# %%
years_list_iqr = []
iqr_list_bmi_female = []
iqr_q1_list_bmi_female = []
iqr_q3_list_bmi_female = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_bmi_female.append(round(iqr, 2))
    iqr_q1_list_bmi_female.append(round(q1, 2))
    iqr_q3_list_bmi_female.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_bmi_female, '75%': iqr_q3_list_bmi_female, 'iqr': iqr_list_bmi_female}

bmif_american_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### European region

# %%
years_list_iqr = []
iqr_list_bmi_female = []
iqr_q1_list_bmi_female = []
iqr_q3_list_bmi_female = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_bmi_female.append(round(iqr, 2))
    iqr_q1_list_bmi_female.append(round(q1, 2))
    iqr_q3_list_bmi_female.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_bmi_female, '75%': iqr_q3_list_bmi_female, 'iqr': iqr_list_bmi_female}

bmif_european_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_iqr = []
iqr_list_bmi_female = []
iqr_q1_list_bmi_female = []
iqr_q3_list_bmi_female = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['bmi_female'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_bmi_female.append(round(iqr, 2))
    iqr_q1_list_bmi_female.append(round(q1, 2))
    iqr_q3_list_bmi_female.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_bmi_female, '75%': iqr_q3_list_bmi_female, 'iqr': iqr_list_bmi_female}

bmif_oceania_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# ### Combining stats into single dataframe and converting it into a csv file

# %%
# Al countries
descriptive_stats_bmi_female =all_means_df.merge(all_max_df, on='year').merge(all_min_df, on='year').merge(all_median_df, on='year').merge(all_std_df, on='year').merge(am_all_iqr_df, on='year')
descriptive_stats_bmi_female.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_All_Dfs/Descriptive_Stats_All_bmi_female.csv')

# Africa
descriptive_stats_bmi_female_africa =african_mean_df.merge(african_max_df, on='year').merge(african_min_df, on='year').merge(african_median_df, on='year').merge(african_std_df, on='year').merge(am_african_iqr_df, on='year')
descriptive_stats_bmi_female_africa.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/BMI_Female/Descriptive_Stats_Africa_bmi_female.csv')

# Asia
descriptive_stats_bmi_female_asia =asian_mean_df.merge(asian_max_df, on='year').merge(asian_min_df, on='year').merge(asian_median_df, on='year').merge(asian_std_df, on='year').merge(am_asian_iqr_df, on='year')
descriptive_stats_bmi_female_asia.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/BMI_Female/Descriptive_Stats_Asia_bmi_female.csv')

# America
descriptive_stats_bmi_female_america =american_mean_df.merge(american_max_df, on='year').merge(american_min_df, on='year').merge(american_median_df, on='year').merge(american_std_df, on='year').merge(am_american_iqr_df, on='year')
descriptive_stats_bmi_female_america.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/BMI_Female/Descriptive_Stats_America_bmi_female.csv')

# Europe
descriptive_stats_bmi_female_europe =european_mean_df.merge(european_max_df, on='year').merge(european_min_df, on='year').merge(european_median_df, on='year').merge(european_std_df, on='year').merge(am_european_iqr_df, on='year')
descriptive_stats_bmi_female_europe.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/BMI_Female/Descriptive_Stats_Europe_bmi_female.csv')

# Oceania
descriptive_stats_bmi_female_oceania =oceania_mean_df.merge(oceania_max_df, on='year').merge(oceania_min_df, on='year').merge(oceania_median_df, on='year').merge(oceania_std_df, on='year').merge(am_oceania_iqr_df, on='year')
descriptive_stats_bmi_female_oceania.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/BMI_Female/Descriptive_Stats_Oceania_bmi_female.csv')

# %% [markdown]
# ## Health Expenditure Percentage

# %% [markdown]
# ### Mean

# %% [markdown]
# #### Al countries

# %%
years_list_mean = []
means_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['health_expenditure_percentage'].where(life_expectancy.year == year))
    years_list_mean.append(year)
    means_list_health_expenditure_percentage.append(np.round(mean, 2))
all_means_dict = {'year': years_list_mean, 'mean': means_list_health_expenditure_percentage}

all_means_df = pd.DataFrame(all_means_dict)

# %% [markdown]
# #### African region

# %%
years_list_mean = []
mean_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_mean.append(year)
    mean_list_health_expenditure_percentage.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_health_expenditure_percentage}

african_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_mean = []
mean_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_mean.append(year)
    mean_list_health_expenditure_percentage.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_health_expenditure_percentage}

asian_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### American region

# %%
years_list_mean= []
mean_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    mean= np.mean(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_mean.append(year)
    mean_list_health_expenditure_percentage.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_health_expenditure_percentage}

american_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### European region

# %%
years_list_mean = []
mean_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_mean.append(year)
    mean_list_health_expenditure_percentage.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_health_expenditure_percentage}

european_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_mean = []
mean_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_mean.append(year)
    mean_list_health_expenditure_percentage.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_health_expenditure_percentage}

oceania_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# ### Max

# %% [markdown]
# #### Al countries

# %%
years_list_max = []
max_list_health_expenditure_percentage = []
max_countries_health_expenditure_percentage = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['health_expenditure_percentage'][life_expectancy.year == year])
    max_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['health_expenditure_percentage'] == max)].values[0]
    years_list_max.append(year)
    max_list_health_expenditure_percentage.append(max)
    max_countries_health_expenditure_percentage.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list_health_expenditure_percentage, 'max_countries': max_countries_health_expenditure_percentage}

all_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### African region

# %%
years_list_max = []
max_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_max.append(year)
    max_list_health_expenditure_percentage.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_health_expenditure_percentage}

african_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_max = []
max_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_max.append(year)
    max_list_health_expenditure_percentage.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_health_expenditure_percentage}

asian_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### American region

# %%
years_list_max= []
max_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    max= np.max(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_max.append(year)
    max_list_health_expenditure_percentage.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_health_expenditure_percentage}

american_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### European region

# %%
years_list_max = []
max_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_max.append(year)
    max_list_health_expenditure_percentage.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_health_expenditure_percentage}

european_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_max = []
max_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_max.append(year)
    max_list_health_expenditure_percentage.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_health_expenditure_percentage}

oceania_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# ### Minimum

# %% [markdown]
# #### All countries

# %%
years_list_min = []
min_list_health_expenditure_percentage = []
min_countries_health_expenditure_percentage = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['health_expenditure_percentage'].where(life_expectancy.year == year))
    min_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['health_expenditure_percentage'] == min)].values[0]
    years_list_min.append(year)
    min_list_health_expenditure_percentage.append(min)
    min_countries_health_expenditure_percentage.append(min_country)
all_min_dict = {'year': years_list_min, 'minimum': min_list_health_expenditure_percentage, 'min_countries' : min_countries_health_expenditure_percentage}

all_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### African region

# %%
years_list_min = []
min_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_min.append(year)
    min_list_health_expenditure_percentage.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_health_expenditure_percentage}

african_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_min = []
min_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_min.append(year)
    min_list_health_expenditure_percentage.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_health_expenditure_percentage}

asian_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### American region

# %%
years_list_min= []
min_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    min= np.min(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_min.append(year)
    min_list_health_expenditure_percentage.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_health_expenditure_percentage}

american_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### European region

# %%
years_list_min = []
min_list_health_expenditure_percentage= []
for year in range(2000, 2016):
    min = np.min(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_min.append(year)
    min_list_health_expenditure_percentage.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_health_expenditure_percentage}

european_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_min = []
min_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_min.append(year)
    min_list_health_expenditure_percentage.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_health_expenditure_percentage}

oceania_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# ### Median

# %% [markdown]
# #### All countries

# %%
years_list_median = []
median_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    median = np.median((life_expectancy['health_expenditure_percentage'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_median.append(year)
    median_list_health_expenditure_percentage.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_health_expenditure_percentage}

all_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### African region

# %%
years_list_median = []
median_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_median.append(year)
    median_list_health_expenditure_percentage.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_health_expenditure_percentage}

african_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_median = []
median_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_median.append(year)
    median_list_health_expenditure_percentage.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_health_expenditure_percentage}

asian_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### American region

# %%
years_list_median= []
median_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    median= np.median(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_median.append(year)
    median_list_health_expenditure_percentage.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_health_expenditure_percentage}

american_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### European region

# %%
years_list_median = []
median_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_median.append(year)
    median_list_health_expenditure_percentage.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_health_expenditure_percentage}

european_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_median = []
median_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_median.append(year)
    median_list_health_expenditure_percentage.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_health_expenditure_percentage}

oceania_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# ### Standard Deviation

# %% [markdown]
# #### All countries

# %%
years_list_std = []
std_list = []
for year in range(2000, 2016):
    std = np.std((life_expectancy['health_expenditure_percentage'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_std.append(year)
    std_list.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list}

all_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### African region

# %%
years_list_std = []
std_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_std.append(year)
    std_list_health_expenditure_percentage.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_health_expenditure_percentage}

african_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_std = []
std_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_std.append(year)
    std_list_health_expenditure_percentage.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_health_expenditure_percentage}

asian_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### American region

# %%
years_list_std = []
std_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    std= np.std(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_std.append(year)
    std_list_health_expenditure_percentage.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_health_expenditure_percentage}

american_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### European region

# %%
years_list_std = []
std_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_std.append(year)
    std_list_health_expenditure_percentage.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_health_expenditure_percentage}

european_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_std = []
std_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_std.append(year)
    std_list_health_expenditure_percentage.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_health_expenditure_percentage}

oceania_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# ### Inter-Quartile Range

# %% [markdown]
# #### All countries

# %%
years_list_iqr = []
iqr_list = []
iqr_q1_list_adult_mortality = []
iqr_q3_list_adult_mortality = []
for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['adult_mortality'][life_expectancy['year'] == year], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list.append(round(iqr, 2))
    iqr_q1_list_adult_mortality.append(round(q1, 2))
    iqr_q3_list_adult_mortality.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_adult_mortality, '75%': iqr_q3_list_adult_mortality, 'iqr': iqr_list}

am_all_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### African region

# %%
years_list_iqr = []
iqr_list_adult_mortality = []
iqr_q1_list_adult_mortality = []
iqr_q3_list_adult_mortality = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_adult_mortality.append(round(iqr, 2))
    iqr_q1_list_adult_mortality.append(round(q1, 2))
    iqr_q3_list_adult_mortality.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_adult_mortality, '75%': iqr_q3_list_adult_mortality, 'iqr': iqr_list_adult_mortality}

am_african_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_iqr = []
iqr_list_adult_mortality = []
iqr_q1_list_adult_mortality = []
iqr_q3_list_adult_mortality = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_adult_mortality.append(round(iqr, 2))
    iqr_q1_list_adult_mortality.append(round(q1, 2))
    iqr_q3_list_adult_mortality.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_adult_mortality, '75%': iqr_q3_list_adult_mortality, 'iqr': iqr_list_adult_mortality}

am_asian_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### American region

# %%
years_list_iqr = []
iqr_list_adult_mortality = []
iqr_q1_list_adult_mortality = []
iqr_q3_list_adult_mortality = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_adult_mortality.append(round(iqr, 2))
    iqr_q1_list_adult_mortality.append(round(q1, 2))
    iqr_q3_list_adult_mortality.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_adult_mortality, '75%': iqr_q3_list_adult_mortality, 'iqr': iqr_list_adult_mortality}

am_american_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### European region

# %%
years_list_iqr = []
iqr_list_adult_mortality = []
iqr_q1_list_adult_mortality = []
iqr_q3_list_adult_mortality = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_adult_mortality.append(round(iqr, 2))
    iqr_q1_list_adult_mortality.append(round(q1, 2))
    iqr_q3_list_adult_mortality.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_adult_mortality, '75%': iqr_q3_list_adult_mortality, 'iqr': iqr_list_adult_mortality}

am_european_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_iqr = []
iqr_list_adult_mortality = []
iqr_q1_list_adult_mortality = []
iqr_q3_list_adult_mortality = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['adult_mortality'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_adult_mortality.append(round(iqr, 2))
    iqr_q1_list_adult_mortality.append(round(q1, 2))
    iqr_q3_list_adult_mortality.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_adult_mortality, '75%': iqr_q3_list_adult_mortality, 'iqr': iqr_list_adult_mortality}

am_oceania_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# ### Combining stats into single dataframe and converting it into a csv file

# %%
# Al countries
descriptive_stats_adult_mortality =am_all_means_df.merge(am_all_max_df, on='year').merge(am_all_min_df, on='year').merge(am_all_median_df, on='year').merge(am_all_std_df, on='year').merge(am_all_std_df, on='year').merge(am_all_iqr_df, on='year')
descriptive_stats_adult_mortality.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_All_Dfs/Descriptive_Stats_All_Adult_Mortality.csv')

# Africa
descriptive_stats_adult_mortality_africa =am_african_mean_df.merge(am_african_max_df, on='year').merge(am_african_min_df, on='year').merge(am_african_median_df, on='year').merge(am_african_std_df, on='year').merge(am_african_iqr_df, on='year')
descriptive_stats_adult_mortality_africa.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Adult_Mortality/Descriptive_Stats_Africa_Adult_Mortality.csv')

# Asia
descriptive_stats_adult_mortality_asia =am_asian_mean_df.merge(am_asian_max_df, on='year').merge(am_asian_min_df, on='year').merge(am_asian_median_df, on='year').merge(am_asian_std_df, on='year').merge(am_asian_iqr_df, on='year')
descriptive_stats_adult_mortality_asia.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Adult_Mortality/Descriptive_Stats_Asia_Adult_Mortality.csv')

# America
descriptive_stats_adult_mortality_america = am_american_mean_df.merge(am_merican_max_df, on='year').merge(am_american_min_df, on='year').merge(am_american_median_df, on='year').merge(am_american_std_df, on='year').merge(am_american_iqr_df, on='year')
descriptive_stats_adult_mortality_america.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Adult_Mortality/Descriptive_Stats_America_Adult_Mortality.csv')

# Europe
descriptive_stats_adult_mortality_europe =am_european_mean_df.merge(am_european_max_df, on='year').merge(am_european_min_df, on='year').merge(am_european_median_df, on='year').merge(am_european_std_df, on='year').merge(am_european_iqr_df, on='year')
descriptive_stats_adult_mortality_europe.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Adult_Mortality/Descriptive_Stats_Europe_Adult_Mortality.csv')

# Oceania
descriptive_stats_adult_mortality_oceania =am_oceania_median_df.merge(am_oceania_max_df, on='year').merge(am_oceania_min_df, on='year').merge(am_oceania_median_df, on='year').merge(am_oceania_std_df, on='year').merge(am_oceania_iqr_df, on='year')
descriptive_stats_adult_mortality_oceania.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Adult_Mortality/Descriptive_Stats_Oceania_Adult_Mortality.csv')

# %% [markdown]
# ### Combining stats into single dataframe and converting it into a csv file

# %%
# Al countries
descriptive_stats_health_expenditure_percentage =all_means_df.merge(all_max_df, on='year').merge(all_min_df, on='year').merge(all_median_df, on='year').merge(all_std_df, on='year')
descriptive_stats_health_expenditure_percentage.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_All_Dfs/Descriptive_Stats_All_health_expenditure_percentage.csv')

# Africa
descriptive_stats_health_expenditure_percentage_africa =african_mean_df.merge(african_max_df, on='year').merge(african_min_df, on='year').merge(african_median_df, on='year').merge(all_std_df, on='year')
descriptive_stats_health_expenditure_percentage_africa.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Health_Expenditure_Percentage/Descriptive_Stats_Africa_health_expenditure_percentage.csv')

# Asia
descriptive_stats_health_expenditure_percentage_asia =asian_mean_df.merge(asian_max_df, on='year').merge(asian_min_df, on='year').merge(asian_median_df, on='year').merge(asian_std_df, on='year')
descriptive_stats_health_expenditure_percentage_asia.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Health_Expenditure_Percentage/Descriptive_Stats_Asia_health_expenditure_percentage.csv')

# America
descriptive_stats_health_expenditure_percentage_america =american_mean_df.merge(american_max_df, on='year').merge(american_min_df, on='year').merge(american_median_df, on='year').merge(american_std_df, on='year')
descriptive_stats_health_expenditure_percentage_america.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Health_Expenditure_Percentage/Descriptive_Stats_America_health_expenditure_percentage.csv')

# Europe
descriptive_stats_health_expenditure_percentage_europe =european_mean_df.merge(european_max_df, on='year').merge(european_min_df, on='year').merge(european_median_df, on='year').merge(european_std_df, on='year')
descriptive_stats_health_expenditure_percentage_europe.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Health_Expenditure_Percentage/Descriptive_Stats_Europe_health_expenditure_percentage.csv')

# Oceania
descriptive_stats_health_expenditure_percentage_oceania =oceania_mean_df.merge(oceania_max_df, on='year').merge(oceania_min_df, on='year').merge(oceania_median_df, on='year').merge(oceania_std_df, on='year')
descriptive_stats_health_expenditure_percentage_oceania.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Health_Expenditure_Percentage/Descriptive_Stats_Oceania_health_expenditure_percentage.csv')

# %% [markdown]
# ## Total Health Expenditure (Government)

# %% [markdown]
# ### Mean

# %% [markdown]
# #### Al countries

# %%
years_list_mean = []
means_list_total_expenditure = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['total_expenditure'].where(life_expectancy.year == year))
    years_list_mean.append(year)
    means_list_total_expenditure.append(np.round(mean, 2))
all_means_dict = {'year': years_list_mean, 'mean': means_list_total_expenditure}

all_means_df = pd.DataFrame(all_means_dict)

# %% [markdown]
# #### African region

# %%
years_list_mean = []
mean_list_total_expenditure = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_mean.append(year)
    mean_list_total_expenditure.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_total_expenditure}

african_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_mean = []
mean_list_total_expenditure = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_mean.append(year)
    mean_list_total_expenditure.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_total_expenditure}

asian_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### American region

# %%
years_list_mean= []
mean_list_total_expenditure = []
for year in range(2000, 2016):
    mean= np.mean(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_mean.append(year)
    mean_list_total_expenditure.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_total_expenditure}

american_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### European region

# %%
years_list_mean = []
mean_list_total_expenditure = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_mean.append(year)
    mean_list_total_expenditure.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_total_expenditure}

european_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_mean = []
mean_list_total_expenditure = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_mean.append(year)
    mean_list_total_expenditure.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_total_expenditure}

oceania_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# ### Max

# %% [markdown]
# #### Al countries

# %%
years_list_max = []
max_list_total_expenditure = []
max_countries_total_expenditure = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['total_expenditure'][life_expectancy.year == year])
    max_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['total_expenditure'] == max)].values[0]
    years_list_max.append(year)
    max_list_total_expenditure.append(max)
    max_countries_total_expenditure.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list_total_expenditure, 'max_countries': max_countries_total_expenditure}

all_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### African region

# %%
years_list_max = []
max_list_total_expenditure = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_max.append(year)
    max_list_total_expenditure.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_total_expenditure}

african_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_max = []
max_list_total_expenditure = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_max.append(year)
    max_list_total_expenditure.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_total_expenditure}

asian_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### American region

# %%
years_list_max= []
max_list_total_expenditure = []
for year in range(2000, 2016):
    max= np.max(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_max.append(year)
    max_list_total_expenditure.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_total_expenditure}

american_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### European region

# %%
years_list_max = []
max_list_total_expenditure = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_max.append(year)
    max_list_total_expenditure.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_total_expenditure}

european_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_max = []
max_list_total_expenditure = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_max.append(year)
    max_list_total_expenditure.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_total_expenditure}

oceania_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# ### Minimum

# %% [markdown]
# #### All countries

# %%
years_list_min = []
min_list_total_expenditure = []
min_countries_total_expenditure = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['total_expenditure'].where(life_expectancy.year == year))
    min_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['total_expenditure'] == min)].values[0]
    years_list_min.append(year)
    min_list_total_expenditure.append(min)
    min_countries_total_expenditure.append(min_country)
all_min_dict = {'year': years_list_min, 'minimum': min_list_total_expenditure, 'min_countries' : min_countries_total_expenditure}

all_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### African region

# %%
years_list_min = []
min_list_total_expenditure = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_min.append(year)
    min_list_total_expenditure.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_total_expenditure}

african_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_min = []
min_list_total_expenditure = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_min.append(year)
    min_list_total_expenditure.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_total_expenditure}

asian_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### American region

# %%
years_list_min= []
min_list_total_expenditure = []
for year in range(2000, 2016):
    min= np.min(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_min.append(year)
    min_list_total_expenditure.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_total_expenditure}

american_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### European region

# %%
years_list_min = []
min_list_total_expenditure= []
for year in range(2000, 2016):
    min = np.min(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_min.append(year)
    min_list_total_expenditure.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_total_expenditure}

european_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_min = []
min_list_total_expenditure = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_min.append(year)
    min_list_total_expenditure.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_total_expenditure}

oceania_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# ### Median

# %% [markdown]
# #### All countries

# %%
years_list_median = []
median_list_total_expenditure = []
for year in range(2000, 2016):
    median = np.median((life_expectancy['total_expenditure'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_median.append(year)
    median_list_total_expenditure.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_total_expenditure}

all_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### African region

# %%
years_list_median = []
median_list_total_expenditure = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_median.append(year)
    median_list_total_expenditure.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_total_expenditure}

african_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_median = []
median_list_total_expenditure = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_median.append(year)
    median_list_total_expenditure.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_total_expenditure}

asian_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### American region

# %%
years_list_median= []
median_list_total_expenditure = []
for year in range(2000, 2016):
    median= np.median(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_median.append(year)
    median_list_total_expenditure.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_total_expenditure}

american_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### European region

# %%
years_list_median = []
median_list_total_expenditure = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_median.append(year)
    median_list_total_expenditure.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_total_expenditure}

european_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_median = []
median_list_total_expenditure = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_median.append(year)
    median_list_total_expenditure.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_total_expenditure}

oceania_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# ### Standard Deviation

# %% [markdown]
# #### All countries

# %%
years_list_std = []
std_list = []
for year in range(2000, 2016):
    std = np.std((life_expectancy['total_expenditure'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_std.append(year)
    std_list.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list}

all_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### African region

# %%
years_list_std = []
std_list_total_expenditure = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_std.append(year)
    std_list_total_expenditure.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_total_expenditure}

african_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_std = []
std_list_total_expenditure = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_std.append(year)
    std_list_total_expenditure.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_total_expenditure}

asian_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### American region

# %%
years_list_std = []
std_list_total_expenditure = []
for year in range(2000, 2016):
    std= np.std(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_std.append(year)
    std_list_total_expenditure.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_total_expenditure}

american_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### European region

# %%
years_list_std = []
std_list_total_expenditure = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_std.append(year)
    std_list_total_expenditure.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_total_expenditure}

european_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_std = []
std_list_total_expenditure = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['total_expenditure'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_std.append(year)
    std_list_total_expenditure.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_total_expenditure}

oceania_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# ### Inter-Quartile Range

# %% [markdown]
# #### All countries

# %%
years_list_iqr = []
iqr_list = []
iqr_q1_list_health_expenditure_percentage = []
iqr_q3_list_health_expenditure_percentage = []
for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['health_expenditure_percentage'][life_expectancy['year'] == year], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list.append(round(iqr, 2))
    iqr_q1_list_health_expenditure_percentage.append(round(q1, 2))
    iqr_q3_list_health_expenditure_percentage.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_health_expenditure_percentage, '75%': iqr_q3_list_health_expenditure_percentage, 'iqr': iqr_list}

hep_all_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### African region

# %%
years_list_iqr = []
iqr_list_health_expenditure_percentage = []
iqr_q1_list_health_expenditure_percentage = []
iqr_q3_list_health_expenditure_percentage = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_health_expenditure_percentage.append(round(iqr, 2))
    iqr_q1_list_health_expenditure_percentage.append(round(q1, 2))
    iqr_q3_list_health_expenditure_percentage.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_health_expenditure_percentage, '75%': iqr_q3_list_health_expenditure_percentage, 'iqr': iqr_list_health_expenditure_percentage}

hep_african_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_iqr = []
iqr_list_health_expenditure_percentage = []
iqr_q1_list_health_expenditure_percentage = []
iqr_q3_list_health_expenditure_percentage = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_health_expenditure_percentage.append(round(iqr, 2))
    iqr_q1_list_health_expenditure_percentage.append(round(q1, 2))
    iqr_q3_list_health_expenditure_percentage.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_health_expenditure_percentage, '75%': iqr_q3_list_health_expenditure_percentage, 'iqr': iqr_list_health_expenditure_percentage}

hep_asian_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### American region

# %%
years_list_iqr = []
iqr_list_health_expenditure_percentage = []
iqr_q1_list_health_expenditure_percentage = []
iqr_q3_list_health_expenditure_percentage = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_health_expenditure_percentage.append(round(iqr, 2))
    iqr_q1_list_health_expenditure_percentage.append(round(q1, 2))
    iqr_q3_list_health_expenditure_percentage.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_health_expenditure_percentage, '75%': iqr_q3_list_health_expenditure_percentage, 'iqr': iqr_list_health_expenditure_percentage}

hep_american_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### European region

# %%
years_list_iqr = []
iqr_list_health_expenditure_percentage = []
iqr_q1_list_health_expenditure_percentage = []
iqr_q3_list_health_expenditure_percentage = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_health_expenditure_percentage.append(round(iqr, 2))
    iqr_q1_list_health_expenditure_percentage.append(round(q1, 2))
    iqr_q3_list_health_expenditure_percentage.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_health_expenditure_percentage, '75%': iqr_q3_list_health_expenditure_percentage, 'iqr': iqr_list_health_expenditure_percentage}

hep_european_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_iqr = []
iqr_list_health_expenditure_percentage = []
iqr_q1_list_health_expenditure_percentage = []
iqr_q3_list_health_expenditure_percentage = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['health_expenditure_percentage'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_health_expenditure_percentage.append(round(iqr, 2))
    iqr_q1_list_health_expenditure_percentage.append(round(q1, 2))
    iqr_q3_list_health_expenditure_percentage.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_health_expenditure_percentage, '75%': iqr_q3_list_health_expenditure_percentage, 'iqr': iqr_list_health_expenditure_percentage}

hep_oceania_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# ### Combining stats into single dataframe and converting it into a csv file

# %%
# Al countries
descriptive_stats_total_expenditure =all_means_df.merge(all_max_df, on='year').merge(all_min_df, on='year').merge(all_median_df, on='year').merge(all_std_df, on='year').merge(am_all_iqr_df, on='year')
descriptive_stats_total_expenditure.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_All_Dfs/Descriptive_Stats_All_total_expenditure.csv')

# Africa
descriptive_stats_total_expenditure_africa =african_mean_df.merge(african_max_df, on='year').merge(african_min_df, on='year').merge(african_median_df, on='year').merge(african_std_df, on='year').merge(am_african_iqr_df, on='year')
descriptive_stats_total_expenditure_africa.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Total_Health_Expenditure/Descriptive_Stats_Africa_total_expenditure.csv')

# Asia
descriptive_stats_total_expenditure_asia =asian_mean_df.merge(asian_max_df, on='year').merge(asian_min_df, on='year').merge(asian_median_df, on='year').merge(asian_std_df, on='year').merge(am_asian_iqr_df, on='year')
descriptive_stats_total_expenditure_asia.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Total_Health_Expenditure/Descriptive_Stats_Asia_total_expenditure.csv')

# America
descriptive_stats_total_expenditure_america =american_mean_df.merge(american_max_df, on='year').merge(american_min_df, on='year').merge(american_median_df, on='year').merge(american_std_df, on='year').merge(am_american_iqr_df, on='year')
descriptive_stats_total_expenditure_america.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Total_Health_Expenditure/Descriptive_Stats_America_total_expenditure.csv')

# Europe
descriptive_stats_total_expenditure_europe =european_mean_df.merge(european_max_df, on='year').merge(european_min_df, on='year').merge(european_median_df, on='year').merge(european_std_df, on='year').merge(am_european_iqr_df, on='year')
descriptive_stats_total_expenditure_europe.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Total_Health_Expenditure/Descriptive_Stats_Europe_total_expenditure.csv')

# Oceania
descriptive_stats_total_expenditure_oceania =oceania_mean_df.merge(oceania_max_df, on='year').merge(oceania_min_df, on='year').merge(oceania_median_df, on='year').merge(oceania_std_df, on='year').merge(am_oceania_iqr_df, on='year')
descriptive_stats_total_expenditure_oceania.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Total_Health_Expenditure/Descriptive_Stats_Oceania_total_expenditure.csv')

# %% [markdown]
# ## Population

# %% [markdown]
# ### Mean

# %% [markdown]
# #### Al countries

# %%
years_list_mean = []
means_list_population = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['population'].where(life_expectancy.year == year))
    years_list_mean.append(year)
    means_list_population.append(np.round(mean, 2))
all_means_dict = {'year': years_list_mean, 'mean': means_list_population}

all_means_df = pd.DataFrame(all_means_dict)

# %% [markdown]
# #### African region

# %%
years_list_mean = []
mean_list_population = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_mean.append(year)
    mean_list_population.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_population}

african_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_mean = []
mean_list_population = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_mean.append(year)
    mean_list_population.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_population}

asian_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### American region

# %%
years_list_mean= []
mean_list_population = []
for year in range(2000, 2016):
    mean= np.mean(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_mean.append(year)
    mean_list_population.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_population}

american_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### European region

# %%
years_list_mean = []
mean_list_population = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_mean.append(year)
    mean_list_population.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_population}

european_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_mean = []
mean_list_population = []
for year in range(2000, 2016):
    mean = np.mean(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_mean.append(year)
    mean_list_population.append(round(mean, 2))
all_mean_dict = {'year': years_list_mean, 'mean': mean_list_population}

oceania_mean_df = pd.DataFrame(all_mean_dict)

# %% [markdown]
# ### Max

# %% [markdown]
# #### Al countries

# %%
years_list_max = []
max_list_population = []
max_countries_population = []

for year in range(2000, 2016):
    max = np.max(life_expectancy['population'][life_expectancy.year == year])
    max_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['population'] == max)].values[0]
    years_list_max.append(year)
    max_list_population.append(max)
    max_countries_population.append(max_country)
all_max_dict = {'year': years_list_max, 'max': max_list_population, 'max_countries': max_countries_population}

all_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### African region

# %%
years_list_max = []
max_list_population = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_max.append(year)
    max_list_population.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_population}

african_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_max = []
max_list_population = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_max.append(year)
    max_list_population.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_population}

asian_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### American region

# %%
years_list_max= []
max_list_population = []
for year in range(2000, 2016):
    max= np.max(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_max.append(year)
    max_list_population.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_population}

american_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### European region

# %%
years_list_max = []
max_list_population = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_max.append(year)
    max_list_population.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_population}

european_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_max = []
max_list_population = []
for year in range(2000, 2016):
    max = np.max(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_max.append(year)
    max_list_population.append(round(max, 2))
all_max_dict = {'year': years_list_max, 'max': max_list_population}

oceania_max_df = pd.DataFrame(all_max_dict)

# %% [markdown]
# ### Minimum

# %% [markdown]
# #### All countries

# %%
years_list_min = []
min_list_population = []
min_countries_population = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['population'].where(life_expectancy.year == year))
    min_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['population'] == min)].values[0]
    years_list_min.append(year)
    min_list_population.append(min)
    min_countries_population.append(min_country)
all_min_dict = {'year': years_list_min, 'minimum': min_list_population, 'min_countries' : min_countries_population}

all_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### African region

# %%
years_list_min = []
min_list_population = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_min.append(year)
    min_list_population.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_population}

african_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_min = []
min_list_population = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_min.append(year)
    min_list_population.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_population}

asian_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### American region

# %%
years_list_min= []
min_list_population = []
for year in range(2000, 2016):
    min= np.min(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_min.append(year)
    min_list_population.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_population}

american_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### European region

# %%
years_list_min = []
min_list_population= []
for year in range(2000, 2016):
    min = np.min(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_min.append(year)
    min_list_population.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_population}

european_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_min = []
min_list_population = []
for year in range(2000, 2016):
    min = np.min(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_min.append(year)
    min_list_population.append(round(min, 2))
all_min_dict = {'year': years_list_min, 'min': min_list_population}

oceania_min_df = pd.DataFrame(all_min_dict)

# %% [markdown]
# ### Median

# %% [markdown]
# #### All countries

# %%
years_list_median = []
median_list_population = []
for year in range(2000, 2016):
    median = np.median((life_expectancy['population'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_median.append(year)
    median_list_population.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_population}

all_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### African region

# %%
years_list_median = []
median_list_population = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')])
    years_list_median.append(year)
    median_list_population.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_population}

african_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_median = []
median_list_population = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')])
    years_list_median.append(year)
    median_list_population.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_population}

asian_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### American region

# %%
years_list_median= []
median_list_population = []
for year in range(2000, 2016):
    median= np.median(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')])
    years_list_median.append(year)
    median_list_population.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_population}

american_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### European region

# %%
years_list_median = []
median_list_population = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_median.append(year)
    median_list_population.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_population}

european_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_median = []
median_list_population = []
for year in range(2000, 2016):
    median = np.median(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_median.append(year)
    median_list_population.append(round(median, 2))
all_median_dict = {'year': years_list_median, 'median': median_list_population}

oceania_median_df = pd.DataFrame(all_median_dict)

# %% [markdown]
# ### Standard Deviation

# %% [markdown]
# #### All countries

# %%
years_list_std = []
std_list = []
for year in range(2000, 2016):
    std = np.std((life_expectancy['population'].where(life_expectancy.year == year)).dropna().reset_index(drop=True))
    years_list_std.append(year)
    std_list.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list}

all_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### European region

# %%
years_list_std = []
std_list_population = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')])
    years_list_std.append(year)
    std_list_population.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_population}

european_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_std = []
std_list_population = []
for year in range(2000, 2016):
    std = np.std(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')])
    years_list_std.append(year)
    std_list_population.append(round(std, 2))
all_std_dict = {'year': years_list_std, 'std': std_list_population}

oceania_std_df = pd.DataFrame(all_std_dict)

# %% [markdown]
# ### Inter-Quartile Range

# %% [markdown]
# #### All countries

# %%
years_list_iqr = []
iqr_list = []
iqr_q1_list_adult_mortality = []
iqr_q3_list_adult_mortality = []
for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['adult_mortality'][life_expectancy['year'] == year], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list.append(round(iqr, 2))
    iqr_q1_list_adult_mortality.append(round(q1, 2))
    iqr_q3_list_adult_mortality.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_adult_mortality, '75%': iqr_q3_list_adult_mortality, 'iqr': iqr_list}

pop_all_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### African region

# %%
years_list_iqr = []
iqr_list_population = []
iqr_q1_list_population = []
iqr_q3_list_population = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'African region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_population.append(round(iqr, 2))
    iqr_q1_list_population.append(round(q1, 2))
    iqr_q3_list_population.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_population, '75%': iqr_q3_list_population, 'iqr': iqr_list_population}

pop_african_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Asian region

# %%
years_list_iqr = []
iqr_list_population = []
iqr_q1_list_population = []
iqr_q3_list_population = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Asian region')], [75, 25])
    iqr = q3 - q1
    years_list_iqr.append(year)
    iqr_list_population.append(round(iqr, 2))
    iqr_q1_list_population.append(round(q1, 2))
    iqr_q3_list_population.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_population, '75%': iqr_q3_list_population, 'iqr': iqr_list_population}

pop_asian_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### American region

# %%
years_list_iqr = []
iqr_list_population = []
iqr_q1_list_population = []
iqr_q3_list_population = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'American region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_population.append(round(iqr, 2))
    iqr_q1_list_population.append(round(q1, 2))
    iqr_q3_list_population.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_population, '75%': iqr_q3_list_population, 'iqr': iqr_list_population}

pop_american_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### European region

# %%
years_list_iqr = []
iqr_list_population = []
iqr_q1_list_population = []
iqr_q3_list_population = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'European region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_population.append(round(iqr, 2))
    iqr_q1_list_population.append(round(q1, 2))
    iqr_q3_list_population.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_population, '75%': iqr_q3_list_population, 'iqr': iqr_list_population}

pop_european_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# #### Oceania region

# %%
years_list_iqr = []
iqr_list_population = []
iqr_q1_list_population = []
iqr_q3_list_population = []

for year in range(2000, 2016):
    q3, q1 = np.percentile(life_expectancy['population'][(life_expectancy['year'] == year) & (life_expectancy['region'] == 'Oceania region')], [75, 25])
    years_list_iqr.append(year)
    iqr_list_population.append(round(iqr, 2))
    iqr_q1_list_population.append(round(q1, 2))
    iqr_q3_list_population.append(round(q3, 2))
all_iqr_dict = {'year': years_list_iqr, '25%': iqr_q1_list_population, '75%': iqr_q3_list_population, 'iqr': iqr_list_population}

pop_oceania_iqr_df = pd.DataFrame(all_iqr_dict)

# %% [markdown]
# ### Combining stats into single dataframe and converting it into a csv file

# %%
# Al countries
descriptive_stats_population =all_means_df.merge(all_max_df, on='year').merge(all_min_df, on='year').merge(all_median_df, on='year').merge(all_std_df, on='year').merge(pop_all_iqr_df, on='year')
descriptive_stats_population.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_All_Dfs/Descriptive_Stats_All_population.csv')

# Africa
descriptive_stats_population_africa =african_mean_df.merge(african_max_df, on='year').merge(african_min_df, on='year').merge(african_median_df, on='year').merge(african_std_df, on='year').merge(pop_african_iqr_df, on='year')
descriptive_stats_population_africa.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Population/Descriptive_Stats_Africa_population.csv')

# Asia
descriptive_stats_population_asia =asian_mean_df.merge(asian_max_df, on='year').merge(asian_min_df, on='year').merge(asian_median_df, on='year').merge(asian_std_df, on='year').merge(pop_asian_iqr_df, on='year')
descriptive_stats_population_asia.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Population/Descriptive_Stats_Asia_population.csv')

# America
descriptive_stats_population_america =american_mean_df.merge(american_max_df, on='year').merge(american_min_df, on='year').merge(american_median_df, on='year').merge(american_std_df, on='year').merge(pop_american_iqr_df, on='year')
descriptive_stats_population_america.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Population/Descriptive_Stats_America_population.csv')

# Europe
descriptive_stats_population_europe =european_mean_df.merge(european_max_df, on='year').merge(european_min_df, on='year').merge(european_median_df, on='year').merge(european_std_df, on='year').merge(pop_european_iqr_df, on='year')
descriptive_stats_population_europe.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Population/Descriptive_Stats_Europe_population.csv')

# Oceania
descriptive_stats_population_oceania =oceania_mean_df.merge(oceania_max_df, on='year').merge(oceania_min_df, on='year').merge(oceania_median_df, on='year').merge(oceania_std_df, on='year').merge(pop_oceania_iqr_df, on='year')
descriptive_stats_population_oceania.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_by_region/Population/Descriptive_Stats_Oceania_population.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Relationship between Life expectancy and GDP per capita

# %% [markdown]
# Create dataframe with mean, min, max and median life expectancy aggregates for:
# 1.  Top 20 grossing countries (in 2015) per capita
# 2.  Bottom 20 grossing countries (in 2015) per capita

# %% [markdown]
# ### Top and bottom grossing countries

# %% [markdown]
# Descriptive statistics on the relationship between life expectancy and gdp per capita to illustrate how the wealth of a country influences the quality of health of the country's population.

# %% [markdown]
# #### Mean Life Expectancy

# %%
# 20 Highest grossing countries
years_list_mean = []
means_list_top_gdp = []

for year in range(2000, 2016):
    mean = np.mean(highest_grossing['life_expectancy'].where(highest_grossing.year == year))
    years_list_mean.append(year)
    means_list_top_gdp.append(np.round(mean, 2))
all_means_dict_top = {'year': years_list_mean, 'mean': means_list_top_gdp}

all_means_top_gdp_df = pd.DataFrame(all_means_dict_top)

# 20 Lowest grossing countries
means_list_bottom_gdp = []
for year in range(2000, 2016):
    mean = np.mean(lowest_grossing['life_expectancy'].where(lowest_grossing.year == year))
    means_list_bottom_gdp.append(np.round(mean, 2))
all_means_dict_bottom = {'year': years_list_mean, 'mean': means_list_bottom_gdp}

all_means_bottom_gdp_df = pd.DataFrame(all_means_dict_bottom)

# %% [markdown]
# #### Maximum Life Expectancy

# %%
# 20 Highest grossing countries
years_list_max = []
max_list_top_gdp = []
max_countries_top = []
for year in range(2000, 2016):
    max = np.max(highest_grossing['life_expectancy'].where(highest_grossing.year == year))
    max_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['life_expectancy'] == max)].values[0]
    years_list_max.append(year)
    max_list_top_gdp.append(max)
    max_countries_top.append(max_country)
all_max_dict_top = {'year': years_list_max, 'max': max_list_top_gdp, 'max_country': max_countries_top}

all_max_top_gdp_df = pd.DataFrame(all_max_dict_top)

# 20 Lowest grossing countries
max_list_bottom_gdp = []
max_countries_bottom = []
for year in range(2000, 2016):
    max = np.max(lowest_grossing['life_expectancy'].where(lowest_grossing.year == year))
    max_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['life_expectancy'] == max)].values[0]
    max_list_bottom_gdp.append(max)
    max_countries_bottom.append(max_country)
all_max_dict_bottom = {'year': years_list_max, 'max': max_list_bottom_gdp}

all_max_bottom_gdp_df = pd.DataFrame(all_max_dict_bottom)

# %% [markdown]
# #### Minimum Life Expectancy

# %%
# 20 Highest grossing countries
years_list_min = []
min_list_top_gdp = []
min_countries_top = []
for year in range(2000, 2016):
    min = np.min(highest_grossing['life_expectancy'].where(highest_grossing.year == year))
    min_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['life_expectancy'] == min)].values[0]
    years_list_min.append(year)
    min_list_top_gdp.append(min)
    min_countries_top.append(min_country)
all_min_top_gdp_dict = {'year': years_list_min, 'minimum': min_list_top_gdp}

all_min_top_gdp_df = pd.DataFrame(all_min_top_gdp_dict)

# 20 Lowest grossing countries
min_list_bottom_gdp = []
min_countries_bottom = []
for year in range(2000, 2016):
    min = np.min(lowest_grossing['life_expectancy'].where(lowest_grossing.year == year))
    min_country = life_expectancy['country'][(life_expectancy.year == year) & (life_expectancy['life_expectancy'] == min)].values[0]
    min_list_bottom_gdp.append(min)
    min_countries_bottom.append(min_country)
all_min_bottom_gdp_dict = {'year': years_list_min, 'minimum': min_list_bottom_gdp, 'min_country' : min_countries_bottom}

all_min_bottom_gdp_df = pd.DataFrame(all_min_bottom_gdp_dict)

# %% [markdown]
# #### Median Life Expectancy

# %%
# 20 Highest grossing countries
years_list_median = []
median_list_top_gdp = []
for year in range(2000, 2016):
    median = np.median((highest_grossing['life_expectancy'].where(highest_grossing.year == year)).dropna().reset_index(drop=True))
    years_list_median.append(year)
    median_list_top_gdp.append(round(median, 2))
all_median_top_gdp_dict = {'year': years_list_median, 'median': median_list_top_gdp}

all_median_top_gdp_df = pd.DataFrame(all_median_top_gdp_dict)

# 20 Lowest grossing countries
median_list_bottom_gdp = []
for year in range(2000, 2016):
    median = np.median((lowest_grossing['life_expectancy'].where(lowest_grossing.year == year)).dropna().reset_index(drop=True))
    median_list_bottom_gdp.append(round(median, 2))
all_median_bottom_gdp_dict = {'year': years_list_median, 'median': median_list_bottom_gdp}

all_median_bottom_gdp_df = pd.DataFrame(all_median_bottom_gdp_dict)

# %% [markdown]
# #### Descriptive Stats combination df creation

# %%
# 20 Highest grossing countries
descriptive_stats_life_exp_top_gdp =all_means_top_gdp_df.merge(all_max_top_gdp_df, on='year').merge(all_min_top_gdp_df, on='year').merge(all_median_top_gdp_df, on='year')

# 20 Lowest grossing countries
descriptive_stats_life_exp_bottom_gdp =all_means_bottom_gdp_df.merge(all_max_bottom_gdp_df, on='year').merge(all_min_bottom_gdp_df, on='year').merge(all_median_bottom_gdp_df, on='year')

# %% [markdown]
# #### Save descriptive statistics dataframes as csv files

# %%
descriptive_stats_life_exp_top_gdp.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_All_Dfs/Descriptive_Stats-Top_GDP_Life_expectancy.csv')

descriptive_stats_life_exp_bottom_gdp.to_csv('../Datasets/Cleaned_datasets/Descriptive_Statistics_All_Dfs/Descriptive_Stats-Bottom_GDP_Life_expectancy.csv')

# %% [markdown]
# #### Create datasets for top and bottom 20 gdp per capita

# %% [markdown]
# ##### Top 20 highest grossing per capita countries dataset

# %%
# Manipulating Life Expectancy df descending to retrieve top 20 gdp per capita countries data
le_top_20_gdp_2000 = life_expectancy[life_expectancy['year'] == 2000]
le_top_20_gdp_2000 = le_top_20_gdp_2000.sort_values(by='gdp_per_capita', ascending=False).reset_index(drop=True)

le_top_20_gdp_2000 = le_top_20_gdp_2000.iloc[:20]
top_20_gdp_countries_list = list(le_top_20_gdp_2000['country'])

# Sort df with top 20 countries to match template format
le_top_20_gdp = life_expectancy[life_expectancy['country'].isin(top_20_gdp_countries_list)].sort_values(by=['country', 'year'], ascending=[True, False])

# Create new column which only holds gdp values for year 2015
le_top_20_gdp['gdp_2015'] = le_top_20_gdp.apply(lambda row: row['gdp_per_capita'] if row['year'] == 2015 else pd.NA, axis=1)

# Filling years prior to 2015 with equal values for sorting
le_top_20_gdp['gdp_2015'] = le_top_20_gdp['gdp_2015'].ffill().bfill()
le_top_20_gdp = le_top_20_gdp.infer_objects(copy=False)

# Sorting dataframe to group countries together with descending gdp values
le_top_20_gdp = le_top_20_gdp.sort_values(by=['gdp_2015', 'country', 'year'], ascending=[False, True, False]).reset_index(drop=True).drop(columns='gdp_2015')

le_top_20_gdp.to_csv('../Datasets/Cleaned_datasets/EDA_Datasets/Top_Grossing_Countries-per_capita.csv')
# Out:
# C:\Users\werne\AppData\Local\Temp\ipykernel_6132\779484740.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   le_top_20_gdp['gdp_2015'] = le_top_20_gdp['gdp_2015'].ffill().bfill()

# %% [markdown]
# ##### 20 lowest grossing per capita countries dataset

# %%
# Sorting Life Expectancy df ascending to retrieve bottom 20 gdp per capita countries data
le_bottom_20_gdp_2000 = life_expectancy[life_expectancy['year'] == 2000]
le_bottom_20_gdp_2000 = le_bottom_20_gdp_2000.sort_values(by='gdp_per_capita', ascending=True).reset_index(drop=True)

le_bottom_20_gdp_2000 = le_bottom_20_gdp_2000.iloc[:20]
bottom_20_gdp_countries_list = list(le_bottom_20_gdp_2000['country'])

# Sort df with bottom 20 countries to match template format
le_bottom_20_gdp = life_expectancy[life_expectancy['country'].isin(bottom_20_gdp_countries_list)].sort_values(by=['country', 'year'], ascending=[True, False])

# Create new column which only holds gdp values for year 2015
le_bottom_20_gdp['gdp_2015'] = le_bottom_20_gdp.apply(lambda row: row['gdp_per_capita'] if row['year'] == 2015 else pd.NA, axis=1)

# Filling years prior to 2015 with equal values for sorting
le_bottom_20_gdp['gdp_2015'] = le_bottom_20_gdp['gdp_2015'].ffill().bfill()
le_bottom_20_gdp = le_bottom_20_gdp.infer_objects(copy=False)

# Sorting dataframe to group countries together with descending gdp values
le_bottom_20_gdp = le_bottom_20_gdp.sort_values(by=['gdp_2015', 'country', 'year'], ascending=[False, True, False]).reset_index(drop=True).drop(columns='gdp_2015')

le_bottom_20_gdp.to_csv('../Datasets/Cleaned_datasets/EDA_Datasets/Lowest_Grossing_Countries-per_capita.csv')
# Out:
# C:\Users\werne\AppData\Local\Temp\ipykernel_6132\2596991265.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   le_bottom_20_gdp['gdp_2015'] = le_bottom_20_gdp['gdp_2015'].ffill().bfill()
